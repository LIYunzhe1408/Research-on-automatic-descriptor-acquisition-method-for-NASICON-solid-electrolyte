# %%
import pandas as pd
import numpy as np
from tqdm import trange
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

import torch
import torch.nn as nn
import torch.functional as F
import torchcrf as CRF
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from pytorch_transformers import BertPreTrainedModel, BertModel, BertTokenizer, BertConfig, AdamW

import transformers
from transformers import get_linear_schedule_with_warmup
from seqeval.metrics import f1_score, accuracy_score, classification_report

torch.cuda.set_device(0)

# %%
# 参数设置
# seed = 2021
# max_len = 75
# batch_size = 32
# learning_rate = 3e-5
# epochs = 20
# max_grad_norm = 1.0
# test_size = 0.1
# earlystopping_patience = 3
model_name = "bert-base-cased"
checkpoint_path = "add-lstm-crf-checkpoint.cpt"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def build_corpus1(data_dir):
    """获得句子及标签信息"""
    word_lists = []
    tag_lists = []
    words = []
    tags = []
    data = pd.read_csv(data_dir, header=None, encoding='utf-8')
    word = data.iloc[:, 0]
    tag = data.iloc[:, 2]
    for i in range(len(word)):
        if word[i] != " ":
            words.append(word[i])
            tags.append(tag[i])
        elif word[i] == " ":
            word_lists.append(words)
            tag_lists.append(tags)
            words = []
            tags = []
    return word_lists, tag_lists

def build_corpus2(data_dir):
    word_lists = []
    tag_lists = []
    with open(data_dir, "r", encoding="utf-8") as f:
        words = []
        tags = []
        for line in f:
            if line != "\n":
                word = line.split(" ")[0]
                tag = line.split(" ")[1].strip("\n")
                words.append(word)
                tags.append(tag)
            else:
                word_lists.append(words)
                tag_lists.append(tags)
                words = []
                tags = []
    
    return word_lists, tag_lists

# df = pd.read_csv("./data/DA对比实验数据/top_1k_augmented_sentences.csv", header=None, encoding="utf-8")
# sentences, labels = build_corpus1("./data/DA对比实验数据/top_1k_augmented_sentences.csv")
# sentences, labels = build_corpus2("./mat_data.txt")
df = pd.read_csv("./data_aug.csv", header=None, encoding="utf-8")
sentences, labels = build_corpus1("./data_aug.csv")

# %%
# Ours 数据集
tag_values = list(set(df.iloc[:, 2].values))
tag_values.append("PAD")
tag_values.remove(" ")
tag2idx = {t: i for i, t in enumerate(tag_values)}
print(tag_values)
print(tag2idx)

# ceder 数据集
# tag_values.append("PAD")
# tag2idx = {t: i for i, t in enumerate(tag_values)}
# print(tag_values)
# print(tag2idx)
# Out:
# ['B-Composition', 'I-Property', 'I-Characterization', 'B-Characterization', 'B-Processing', 'B-Structure', 'B-Application', 'I-Composition', 'I-Structure', 'I-Application', 'B-Property', 'I-Processing', 'I-Condition', 'B-Feature', 'B-Condition', 'O', 'I-Feature', 'PAD']
# {'B-Composition': 0, 'I-Property': 1, 'I-Characterization': 2, 'B-Characterization': 3, 'B-Processing': 4, 'B-Structure': 5, 'B-Application': 6, 'I-Composition': 7, 'I-Structure': 8, 'I-Application': 9, 'B-Property': 10, 'I-Processing': 11, 'I-Condition': 12, 'B-Feature': 13, 'B-Condition': 14, 'O': 15, 'I-Feature': 16, 'PAD': 17}

# %%
tokenizer = BertTokenizer.from_pretrained(model_name, do_lower_case=False)

# %%
class BERT_BiLSTM_CRF(BertPreTrainedModel):
    def __init__(self, config, need_birnn=False, rnn_dim=128):
        super(BERT_BiLSTM_CRF, self).__init__(config)
        
        self.num_tags = config.num_labels
        self.bert = BertModel(config)
        self.dropout = nn.Dropout(config.hidden_dropout_prob)
        out_dim = config.hidden_size
        self.need_birnn = need_birnn

        # 如果为False，则不要BiLSTM层
        if need_birnn:
            self.birnn = nn.LSTM(config.hidden_size, rnn_dim, num_layers=1, bidirectional=True, batch_first=True)
            out_dim = rnn_dim*2
        
        self.hidden2tag = nn.Linear(out_dim, config.num_labels)
        self.crf = CRF(config.num_labels, batch_first=True)
    

    def forward(self, input_ids, tags=None, token_type_ids=None, input_mask=None):
        outputs = self.bert(input_ids, token_type_ids=token_type_ids, attention_mask=input_mask)
        sequence_output = outputs[0]
        if self.need_birnn:
            sequence_output, _ = self.birnn(sequence_output)

        sequence_output = self.dropout(sequence_output)
        emissions = self.hidden2tag(sequence_output)
        
        outputs = (emissions,) + outputs[2:]
        if tags is not None:
            loss = -1*self.crf(emissions, tags, mask=input_mask.byte())
            outputs = (loss,) + outputs
            
        return outputs

# %%
torch.cuda.empty_cache()
model = torch.load(checkpoint_path)
# Out:
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.sparse.Embedding' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.normalization.LayerNorm' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.dropout.Dropout' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.linear.Linear' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.activation.Tanh' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torch.nn.modules.rnn.LSTM' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# E:\Anaconda\envs\Jonas\lib\site-packages\torch\serialization.py:786: SourceChangeWarning: source code of class 'torchcrf.CRF' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %% [markdown]
# # 预测

# %%
import pandas as pd
import os
import nltk
import re
from nltk import sent_tokenize, word_tokenize

# %%
# 获取所有txt格式文献
dir_all = "./result_literatures/"
all_text_name_list = []
for home, dirs, files in os.walk(dir_all):
    for filename in files:
        fullname = os.path.join(home, filename)
        all_text_name_list.append(fullname)
all_text_name_list = all_text_name_list[:20]
all_text_name_list
# Out:
# ['./result_literatures/100.txt',
#  './result_literatures/110.txt',
#  './result_literatures/120.txt',
#  './result_literatures/132.txt',
#  './result_literatures/137.txt',
#  './result_literatures/304.txt',
#  './result_literatures/46.txt',
#  './result_literatures/67.txt',
#  './result_literatures/82.txt']

# %%
# 
sigle_sent = []
remove_xkh = r"[(](.*)[)]" 
remove_zkh = r"[\[](.*)[\]]"
remove_dkh = r"[\{](.*)[\}]"
remove_ex1 = r"[\d\)]"

# %%
# 处理文本得到单个句子列表
count = 0
for file in all_text_name_list:
    try:
        with open(file, "r", encoding="utf-8") as f:
            raw_sent_lines = f.readlines()
            sent_size = len(raw_sent_lines)
            index = 0
            cur_sent = ""
            while index < sent_size:
                cur = raw_sent_lines[index].strip()

                if cur != "":
                    cur_sent += (cur + " ")
                    index += 1

                elif cur == "" and cur_sent != "":
                    cur_sent_list = sent_tokenize(cur_sent.strip())
                    sigle_sent.extend(cur_sent_list)
                    cur_sent = ""
                    index += 1

                else:
                    index += 1
            count += 1
            print(file + " ======>已完成!")
    except:
        pass

print(count)

result_sent = []
for sent in sigle_sent:
    if len(sent.split(" ")) <= 8:
        continue
    new_sent1 = re.sub(remove_xkh, '', sent)
    new_sent2 = re.sub(remove_zkh, '', new_sent1)
    new_sent3 = re.sub(remove_dkh, '', new_sent2)
    new_sent4 = re.sub(remove_ex1, '', new_sent3)
    result_sent.append(new_sent4)
# Out:
# ./result_literatures/100.txt ======>已完成!
# ./result_literatures/110.txt ======>已完成!
# ./result_literatures/120.txt ======>已完成!
# ./result_literatures/132.txt ======>已完成!
# ./result_literatures/137.txt ======>已完成!
# ./result_literatures/304.txt ======>已完成!
# ./result_literatures/46.txt ======>已完成!
# ./result_literatures/67.txt ======>已完成!
# ./result_literatures/82.txt ======>已完成!
# 9

# %%
len(result_sent)
# Out:
# 358

# %%
knowledge = {"Composition": {}, "Structure": {}, "Property": {}, "Processing": {}, 
             "Feature": {}, "Application": {}, "Characterization": {}, "Condition": {}}

# %%
def add_new_sent_to_knowledge(sent):
    try:
        tokenized_sentence = tokenizer.encode(sent)
        input_ids = torch.LongTensor([tokenized_sentence])
        input_ids = input_ids.to(device)
        with torch.no_grad():
            output = model(input_ids, tags=None)
        label_indices = np.argmax(output[0].to('cpu').numpy(), axis=2)
        # join bpe split tokens
        tokens = tokenizer.convert_ids_to_tokens(input_ids.to('cpu').numpy()[0])
        new_tokens, new_labels = [], []
        for token, label_idx in zip(tokens, label_indices[0]):
            if token.startswith("##"):
                new_tokens[-1] = new_tokens[-1] + token[2:]
            else:
                new_labels.append(tag_values[label_idx])
                new_tokens.append(token)
    

        tmp_test = [new_tokens, new_labels]
        now_sentence = " ".join(tmp_test[0])
        descriptor_index = []
        for i in range(len(tmp_test[0])):
            if tmp_test[1][i][0] == "B":
                descriptor_index.append(i)
        descriptor_index.append(len(tmp_test[0]))
        descriptor = []
        descriptor_type = []
        for i in range(len(descriptor_index)-1):
            type_ = tmp_test[1][descriptor_index[i]].split("-")[-1]
            descriptor_type.append(type_)
            descriptor_word = []
            for j in range(descriptor_index[i], descriptor_index[i+1]):
                if tmp_test[1][j][0] != "O":
                    descriptor_word.append(tmp_test[0][j])            
            descriptor.append(descriptor_word)
        descriptors = [" ".join(d) for d in descriptor]
        for i in range(len(descriptors)):
            if descriptors[i] not in knowledge[descriptor_type[i]]:
                knowledge[descriptor_type[i]][descriptors[i]] = [now_sentence]
            else:
                knowledge[descriptor_type[i]][descriptors[i]].append(now_sentence)
    except:
        pass

# %%
for sent in result_sent:
    add_new_sent_to_knowledge(sent)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26044\705449732.py in <module>
#       1 for sent in result_sent:
#       2     add_new_sent_to_knowledge(sent)
# ----> 3 knowledge[0]
#
# KeyError: 0

# %%
knowledge['Composition']
# Out:
# {'Na': ['There are two types of concerted migration mechanisms : two Na + ions located at the adjacent Na and Na sites can migrate either in the same direction or at an angle .',
#   'Both mechanisms exhibit relatively low migration barriers owing to the potential energy conversion during the Na + ions migration process .',
#   'Redistribution of Na + ions from the most stable Na sites to Na on increasing Na + total content further facilitates the concerted migration and promotes the Na + ion mobility .',
#   'argued that the Na – Na channel is the only choice for Na + ion diffusion and limited by two triangular bottlenecks in the Na – Na channel .',
#   'Additionally , we reveal concerted migration mechanisms of Na + ions in this system via an improved correlated jump analysis .',
#   'Furthermore , we elucidate the relationship between the Na + content , its distribution , multiple Na + ions concerted migration , and overall Na + diffusion properties .',
#   'We then outline a rational optimization strategy for further enhancing the Na + ion mobility of rhombohedral NASICON - type materials .',
#   'As a consequence , the bottleneck B is likely the limiting factor for Na + ion conduction in the Na – - Na – Na – Na – Na channel .',
#   'However , the size of bottleneck B is slightly smaller than the sum of the O− and Na + radii which needs to be further tailored .',
#   'For the Na – Na – Na – Na channel and the local channels around Na site , Na + ion conduction is likely highly dependent on whether the central Na site is occupied or not .',
#   'If Na site is empty , the Na + at Na might tend to migrate to Na site through the Na – Na segment because the size of the bottleneck A .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'As the Na – Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , while the Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , the difference of the Na – Na and Na – Na segments play the important role in the preference of Na + ion conduction .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'To examine in detail the Na + ion migration mechanism , we scrutinized the site - to - site jump events and timings by tracking the site identity of each Na + ion during the AIMD trajectory , as shown in Figures S and S .',
#   'Moreover , the Na + ions are more likely to stay at the Na site for NaZr , while for Na . ZrSi . P . O they have to occupy both Na and Na sites because there are not enough Na sites for all Na ions and a lot of available Na sites for the extra Na + ions .',
#   'Moreover , the Na + ions are more likely to stay at the Na site for NaZr , while for Na . ZrSi . P . O they have to occupy both Na and Na sites because there are not enough Na sites for all Na ions and a lot of available Na sites for the extra Na + ions .',
#   'In addition , we also find that the Na + ions are not likely to occupy the Na sites as reflected by the short residence time of Na + ion in the NaIIIO polyhedra .',
#   'In addition , we also find that the Na + ions are not likely to occupy the Na sites as reflected by the short residence time of Na + ion in the NaIIIO polyhedra .',
#   'Most importantly , we find that some Na + ions indeed migrate in a cooperative manner as Goodenough et al .',
#   'In addition , the shortest distance between the two Na + ions during the hopping process is less than . Å which indicate there is a strong Coulomb interaction between them , as shown in Figure c , d .',
#   'When extra Na + ions are added to the structure , e . g . , by P / Si substitution , the Coulomb force will push some of the Na + ions into the high energy Na site .',
#   'When extra Na + ions are added to the structure , e . g . , by P / Si substitution , the Coulomb force will push some of the Na + ions into the high energy Na site .',
#   'However , once the Na + ion located at Na site jumps to the adjacent Na site , this local balance will be broken .',
#   'As a result , the Na + ion originally located at the Na site will move toward the next Na site and the strong Coulomb force will push that Na + ion to the next Na site .',
#   'As a result , the Na + ion originally located at the Na site will move toward the next Na site and the strong Coulomb force will push that Na + ion to the next Na site .',
#   'This decrease of the migration barriers for concerted migrations is caused by the potential energy transfer between the ions at high energy Na site and the ions at low energy Na site , i . e . , when the Na + ion at the high energy Na site moves down to the adjacent low energy Na site , the decrease of potential energy would cancel out the required potential energy for the Na + ion at the low energy Na site moving up to another high energy Na site .',
#   'This decrease of the migration barriers for concerted migrations is caused by the potential energy transfer between the ions at high energy Na site and the ions at low energy Na site , i . e . , when the Na + ion at the high energy Na site moves down to the adjacent low energy Na site , the decrease of potential energy would cancel out the required potential energy for the Na + ion at the low energy Na site moving up to another high energy Na site .',
#   'As can be seen , at lower temperature and Na . ZrSi . P . O which indicates that the Na site is a low energy site .',
#   'When the simulation temperature increases , the occupancy of the Na site decreases and those of Na and Na sites increase , which indicates that more Na + ions of the Na sites were activated to Na and Na sites .',
#   'Moreover , when the overall Na + content increases , the occupancies of Na and Na sites also increase markedly due to the Coulomb force of the Na + ions located at Na sites .',
#   'The results indicate that the increase in temperature or Na + concentration leads to the higher occupancies of Na site and the increased number of the Na + configurations of “ Na + Na + Va . ” As mentioned previously , there are three diffusion modes in our systems , i . e . , one type of singe Na + ion migration with the migration barrier of . eV and two types of two Na + ions concerted migration with the migration barrier of . and . eV , respectively .',
#   'As shown in Figure a , with the increase in simulation temperature or Na + concentration , the percentage of correlated jumps increases which indicate that more Na + ions diffuse in the concerted migration mechanism with lower migration barrier .',
#   'This result is likely related to the redistribution of Na + from Na to Na and thus the increasing number of the Na + configurations of “ Na + Na + Va ” , which facilitate the concerted migrations .',
#   'This result is likely related to the redistribution of Na + from Na to Na and thus the increasing number of the Na + configurations of “ Na + Na + Va ” , which facilitate the concerted migrations .',
#   'The overall activation energy determined form AIMD simulations contains the migration energies of different diffusion modes and the energies to form the corresponding Na + ion configurations .',
#   'As shown in Figure b , since Na + ions migration through the concerted migration mechanism has the lower energy barrier , the increase of the percentage of correlated jumps which caused by increasing the Na + concentration will decrease the overall Ea to . eV , which will lead to a high diffusion coefficient and thus a high ionic conductivity at room temperature .',
#   'In this work , we identified the migration channels and bottlenecks in the rhombohedral NASICON and unraveled the preferential migration channel for Na + ion diffusion by crystal structure analysis , BVEL analysis , and AIMD simulations .',
#   'Moreover , two types of concerted migration mechanisms were found : two Na + ions located at the adjacent low - energy Na and high - energy Na sites can migrate either along the same or almost orthogonal directions .',
#   'The Coulomb interactions between these two Na + ions lead to the concerted migration , which in turn lowers the migration barrier due to the potential energy conversion during the Na + ions migration process .',
#   'The Coulomb interactions between these two Na + ions lead to the concerted migration , which in turn lowers the migration barrier due to the potential energy conversion during the Na + ions migration process .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'The doped system was constructed in which one P + is replaced by Si + and a Na + added to maintain overall charge neutrality .',
#   'Nonspin - polarized AIMD simulations were carried out for the canonical ensemble using a Nosé – Hoover thermostat at four elevated temperatures in order to observe the diffusive behavior for the Na + ions over the time scale of the simulations .',
#   'The MSD of the Na + ions were generated using the atomic configuration information from every finite MD time step .',
#   'The tracer diffusion coefficients of Na + ions were estimated based on the slope of the diffusive regime in the MSD plots .',
#   'For the single ion migration , one Na + ion was removed to create a vacancy ; for the multi - ion concerted migration , the Na + - ion concentration was increased by adding a Na + ion .',
#   'For the single ion migration , one Na + ion was removed to create a vacancy ; for the multi - ion concerted migration , the Na + - ion concentration was increased by adding a Na + ion .',
#   'By using this code , except for the site occupancy and the jump events , it could be easily determined whether two jump events are correlated in time and space and further obtain the ratio of the correlated jumps , due to the improvement on determining the position of each Na + during the AIMD simulations .',
#   'Rechargeable seawater batteries are regarded as sustainable alternatives to Li - ion batteries due to the use of an unlimited and free source of Na ion active materials .',
#   'The charge process in this system defines as reducing of the Na + ions and the oxidation of seawater on the anode and cathode , respectively .',
#   'Our team as a pioneer of SWB systems , have put intense efforts toward investigating several concerns for developing anode liquid electrolytes , Na + ion - conductive membranes , electrode materials for the anode , and cathode sides and cell system .',
#   'In the fabricated cell , the cathode and the anode are separated by a square shape solid electrolyte which selectively transfer Na + ions from the seawater to anode part .',
#   'Na - ion conducting membrane is one of the key components of the cell for selective transporting of Na - ion from / to seawater to / from anode compartment .',
#   'A new rectangular cell with Na + ions storing configurations , were designed by connecting NASICON solid electrolyte and carbon cathode current collector .',
#   'The suitability of the BVS methods has been validated particularly for Li and Na host materials , but not for the Ca materials yet .',
#   'There are two types of concerted migration mechanisms : two Na + ions located at the adjacent Na and Na sites can migrate either in the same direction or at an angle .',
#   'Both mechanisms exhibit relatively low migration barriers owing to the potential energy conversion during the Na + ions migration process .',
#   'Redistribution of Na + ions from the most stable Na sites to Na on increasing Na + total content further facilitates the concerted migration and promotes the Na + ion mobility .',
#   'argued that the Na – Na channel is the only choice for Na + ion diffusion and limited by two triangular bottlenecks in the Na – Na channel .',
#   'Additionally , we reveal concerted migration mechanisms of Na + ions in this system via an improved correlated jump analysis .',
#   'Furthermore , we elucidate the relationship between the Na + content , its distribution , multiple Na + ions concerted migration , and overall Na + diffusion properties .',
#   'We then outline a rational optimization strategy for further enhancing the Na + ion mobility of rhombohedral NASICON - type materials .',
#   'As a consequence , the bottleneck B is likely the limiting factor for Na + ion conduction in the Na – - Na – Na – Na – Na channel .',
#   'However , the size of bottleneck B is slightly smaller than the sum of the O− and Na + radii which needs to be further tailored .',
#   'For the Na – Na – Na – Na channel and the local channels around Na site , Na + ion conduction is likely highly dependent on whether the central Na site is occupied or not .',
#   'If Na site is empty , the Na + at Na might tend to migrate to Na site through the Na – Na segment because the size of the bottleneck A .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'As the Na – Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , while the Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , the difference of the Na – Na and Na – Na segments play the important role in the preference of Na + ion conduction .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'To examine in detail the Na + ion migration mechanism , we scrutinized the site - to - site jump events and timings by tracking the site identity of each Na + ion during the AIMD trajectory , as shown in Figures S and S .',
#   'Moreover , the Na + ions are more likely to stay at the Na site for NaZr , while for Na . ZrSi . P . O they have to occupy both Na and Na sites because there are not enough Na sites for all Na ions and a lot of available Na sites for the extra Na + ions .',
#   'Moreover , the Na + ions are more likely to stay at the Na site for NaZr , while for Na . ZrSi . P . O they have to occupy both Na and Na sites because there are not enough Na sites for all Na ions and a lot of available Na sites for the extra Na + ions .',
#   'In addition , we also find that the Na + ions are not likely to occupy the Na sites as reflected by the short residence time of Na + ion in the NaIIIO polyhedra .',
#   'In addition , we also find that the Na + ions are not likely to occupy the Na sites as reflected by the short residence time of Na + ion in the NaIIIO polyhedra .',
#   'Most importantly , we find that some Na + ions indeed migrate in a cooperative manner as Goodenough et al .',
#   'In addition , the shortest distance between the two Na + ions during the hopping process is less than . Å which indicate there is a strong Coulomb interaction between them , as shown in Figure c , d .',
#   'When extra Na + ions are added to the structure , e . g . , by P / Si substitution , the Coulomb force will push some of the Na + ions into the high energy Na site .',
#   'When extra Na + ions are added to the structure , e . g . , by P / Si substitution , the Coulomb force will push some of the Na + ions into the high energy Na site .',
#   'However , once the Na + ion located at Na site jumps to the adjacent Na site , this local balance will be broken .',
#   'As a result , the Na + ion originally located at the Na site will move toward the next Na site and the strong Coulomb force will push that Na + ion to the next Na site .',
#   'As a result , the Na + ion originally located at the Na site will move toward the next Na site and the strong Coulomb force will push that Na + ion to the next Na site .',
#   'This decrease of the migration barriers for concerted migrations is caused by the potential energy transfer between the ions at high energy Na site and the ions at low energy Na site , i . e . , when the Na + ion at the high energy Na site moves down to the adjacent low energy Na site , the decrease of potential energy would cancel out the required potential energy for the Na + ion at the low energy Na site moving up to another high energy Na site .',
#   'This decrease of the migration barriers for concerted migrations is caused by the potential energy transfer between the ions at high energy Na site and the ions at low energy Na site , i . e . , when the Na + ion at the high energy Na site moves down to the adjacent low energy Na site , the decrease of potential energy would cancel out the required potential energy for the Na + ion at the low energy Na site moving up to another high energy Na site .',
#   'As can be seen , at lower temperature and Na . ZrSi . P . O which indicates that the Na site is a low energy site .',
#   'When the simulation temperature increases , the occupancy of the Na site decreases and those of Na and Na sites increase , which indicates that more Na + ions of the Na sites were activated to Na and Na sites .',
#   'Moreover , when the overall Na + content increases , the occupancies of Na and Na sites also increase markedly due to the Coulomb force of the Na + ions located at Na sites .',
#   'The results indicate that the increase in temperature or Na + concentration leads to the higher occupancies of Na site and the increased number of the Na + configurations of “ Na + Na + Va . ” As mentioned previously , there are three diffusion modes in our systems , i . e . , one type of singe Na + ion migration with the migration barrier of . eV and two types of two Na + ions concerted migration with the migration barrier of . and . eV , respectively .',
#   'As shown in Figure a , with the increase in simulation temperature or Na + concentration , the percentage of correlated jumps increases which indicate that more Na + ions diffuse in the concerted migration mechanism with lower migration barrier .',
#   'This result is likely related to the redistribution of Na + from Na to Na and thus the increasing number of the Na + configurations of “ Na + Na + Va ” , which facilitate the concerted migrations .',
#   'This result is likely related to the redistribution of Na + from Na to Na and thus the increasing number of the Na + configurations of “ Na + Na + Va ” , which facilitate the concerted migrations .',
#   'The overall activation energy determined form AIMD simulations contains the migration energies of different diffusion modes and the energies to form the corresponding Na + ion configurations .',
#   'As shown in Figure b , since Na + ions migration through the concerted migration mechanism has the lower energy barrier , the increase of the percentage of correlated jumps which caused by increasing the Na + concentration will decrease the overall Ea to . eV , which will lead to a high diffusion coefficient and thus a high ionic conductivity at room temperature .',
#   'In this work , we identified the migration channels and bottlenecks in the rhombohedral NASICON and unraveled the preferential migration channel for Na + ion diffusion by crystal structure analysis , BVEL analysis , and AIMD simulations .',
#   'Moreover , two types of concerted migration mechanisms were found : two Na + ions located at the adjacent low - energy Na and high - energy Na sites can migrate either along the same or almost orthogonal directions .',
#   'The Coulomb interactions between these two Na + ions lead to the concerted migration , which in turn lowers the migration barrier due to the potential energy conversion during the Na + ions migration process .',
#   'The Coulomb interactions between these two Na + ions lead to the concerted migration , which in turn lowers the migration barrier due to the potential energy conversion during the Na + ions migration process .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'The doped system was constructed in which one P + is replaced by Si + and a Na + added to maintain overall charge neutrality .',
#   'Nonspin - polarized AIMD simulations were carried out for the canonical ensemble using a Nosé – Hoover thermostat at four elevated temperatures in order to observe the diffusive behavior for the Na + ions over the time scale of the simulations .',
#   'The MSD of the Na + ions were generated using the atomic configuration information from every finite MD time step .',
#   'The tracer diffusion coefficients of Na + ions were estimated based on the slope of the diffusive regime in the MSD plots .',
#   'For the single ion migration , one Na + ion was removed to create a vacancy ; for the multi - ion concerted migration , the Na + - ion concentration was increased by adding a Na + ion .',
#   'For the single ion migration , one Na + ion was removed to create a vacancy ; for the multi - ion concerted migration , the Na + - ion concentration was increased by adding a Na + ion .',
#   'By using this code , except for the site occupancy and the jump events , it could be easily determined whether two jump events are correlated in time and space and further obtain the ratio of the correlated jumps , due to the improvement on determining the position of each Na + during the AIMD simulations .',
#   'Rechargeable seawater batteries are regarded as sustainable alternatives to Li - ion batteries due to the use of an unlimited and free source of Na ion active materials .',
#   'The charge process in this system defines as reducing of the Na + ions and the oxidation of seawater on the anode and cathode , respectively .',
#   'Our team as a pioneer of SWB systems , have put intense efforts toward investigating several concerns for developing anode liquid electrolytes , Na + ion - conductive membranes , electrode materials for the anode , and cathode sides and cell system .',
#   'In the fabricated cell , the cathode and the anode are separated by a square shape solid electrolyte which selectively transfer Na + ions from the seawater to anode part .',
#   'Na - ion conducting membrane is one of the key components of the cell for selective transporting of Na - ion from / to seawater to / from anode compartment .',
#   'A new rectangular cell with Na + ions storing configurations , were designed by connecting NASICON solid electrolyte and carbon cathode current collector .',
#   'The suitability of the BVS methods has been validated particularly for Li and Na host materials , but not for the Ca materials yet .'],
#  '+ ions located at the adjacent Na and Na': ['There are two types of concerted migration mechanisms : two Na + ions located at the adjacent Na and Na sites can migrate either in the same direction or at an angle .',
#   'There are two types of concerted migration mechanisms : two Na + ions located at the adjacent Na and Na sites can migrate either in the same direction or at an angle .'],
#  '+ ions migration process .': ['Both mechanisms exhibit relatively low migration barriers owing to the potential energy conversion during the Na + ions migration process .',
#   'The Coulomb interactions between these two Na + ions lead to the concerted migration , which in turn lowers the migration barrier due to the potential energy conversion during the Na + ions migration process .',
#   'Both mechanisms exhibit relatively low migration barriers owing to the potential energy conversion during the Na + ions migration process .',
#   'The Coulomb interactions between these two Na + ions lead to the concerted migration , which in turn lowers the migration barrier due to the potential energy conversion during the Na + ions migration process .'],
#  '+ ions from the most stable Na': ['Redistribution of Na + ions from the most stable Na sites to Na on increasing Na + total content further facilitates the concerted migration and promotes the Na + ion mobility .',
#   'Redistribution of Na + ions from the most stable Na sites to Na on increasing Na + total content further facilitates the concerted migration and promotes the Na + ion mobility .'],
#  'Na on increasing Na +': ['Redistribution of Na + ions from the most stable Na sites to Na on increasing Na + total content further facilitates the concerted migration and promotes the Na + ion mobility .',
#   'Redistribution of Na + ions from the most stable Na sites to Na on increasing Na + total content further facilitates the concerted migration and promotes the Na + ion mobility .'],
#  'NaxZrSix−P−xO for < . and > . is rhombohedral': ['At room temperature , the space group of NaxZrSix−P−xO for x < . and x > . is rhombohedral R−c ( No .',
#   'At room temperature , the space group of NaxZrSix−P−xO for x < . and x > . is rhombohedral R−c ( No .'],
#  'Na – Na': ['suggested that the Na – Na channel is more favorable than the Na – Na channel because the Na – Na channel has the maximum channel opening .',
#   'suggested that the Na – Na channel is more favorable than the Na – Na channel because the Na – Na channel has the maximum channel opening .'],
#  '+ ion diffusion and limited by two triangular bottlenecks in the Na – Na': ['argued that the Na – Na channel is the only choice for Na + ion diffusion and limited by two triangular bottlenecks in the Na – Na channel .',
#   'argued that the Na – Na channel is the only choice for Na + ion diffusion and limited by two triangular bottlenecks in the Na – Na channel .'],
#  'LiN ,': ['Concerted migration mechanism , which involve the simultaneous correlated motion of several atoms appears to be quite common in many fast ion conductors , such as LiN , CaF , AgI , garnet - related lithium ion conductors , LISICON and thio - LISICON analogs , NASICON - type lithium ion conductors , etc .',
#   'Concerted migration mechanism , which involve the simultaneous correlated motion of several atoms appears to be quite common in many fast ion conductors , such as LiN , CaF , AgI , garnet - related lithium ion conductors , LISICON and thio - LISICON analogs , NASICON - type lithium ion conductors , etc .'],
#  'CaF ,': ['Concerted migration mechanism , which involve the simultaneous correlated motion of several atoms appears to be quite common in many fast ion conductors , such as LiN , CaF , AgI , garnet - related lithium ion conductors , LISICON and thio - LISICON analogs , NASICON - type lithium ion conductors , etc .',
#   'Concerted migration mechanism , which involve the simultaneous correlated motion of several atoms appears to be quite common in many fast ion conductors , such as LiN , CaF , AgI , garnet - related lithium ion conductors , LISICON and thio - LISICON analogs , NASICON - type lithium ion conductors , etc .'],
#  'AgI ,': ['Concerted migration mechanism , which involve the simultaneous correlated motion of several atoms appears to be quite common in many fast ion conductors , such as LiN , CaF , AgI , garnet - related lithium ion conductors , LISICON and thio - LISICON analogs , NASICON - type lithium ion conductors , etc .',
#   'Concerted migration mechanism , which involve the simultaneous correlated motion of several atoms appears to be quite common in many fast ion conductors , such as LiN , CaF , AgI , garnet - related lithium ion conductors , LISICON and thio - LISICON analogs , NASICON - type lithium ion conductors , etc .'],
#  'ions in the low': ['further illustrated the reduction of the migration barrier by demonstrating flattening of the energy landscape due to the potential energy transfer from the ions in high energy sites to the ions in the low energy sites during the migration process .',
#   'further illustrated the reduction of the migration barrier by demonstrating flattening of the energy landscape due to the potential energy transfer from the ions in high energy sites to the ions in the low energy sites during the migration process .'],
#  'migration ions to the sites based on convex - hull analysis of site': ['The site occupancy analysis by topology - based method assigns the migration ions to the sites based on convex - hull analysis of site polyhedra .',
#   'The site occupancy analysis by topology - based method assigns the migration ions to the sites based on convex - hull analysis of site polyhedra .'],
#  'Si -': ['In this work , we use the pristine and Si - doped NaZr analysis , and AIMD simulations .',
#   'In this work , we use the pristine and Si - doped NaZr analysis , and AIMD simulations .'],
#  '+ ions in this system via an improved correlated': ['Additionally , we reveal concerted migration mechanisms of Na + ions in this system via an improved correlated jump analysis .',
#   'Additionally , we reveal concerted migration mechanisms of Na + ions in this system via an improved correlated jump analysis .'],
#  '+ ions concerted migration , and overall Na +': ['Furthermore , we elucidate the relationship between the Na + content , its distribution , multiple Na + ions concerted migration , and overall Na + diffusion properties .',
#   'Furthermore , we elucidate the relationship between the Na + content , its distribution , multiple Na + ions concerted migration , and overall Na + diffusion properties .'],
#  '+ ion': ['We then outline a rational optimization strategy for further enhancing the Na + ion mobility of rhombohedral NASICON - type materials .',
#   'We then outline a rational optimization strategy for further enhancing the Na + ion mobility of rhombohedral NASICON - type materials .'],
#  'NaZr .': ['Moreover , according to these coordination polyhedra , we can partition the NaZr .',
#   'The average site occupancies of the different Na sites show that all the Na sites are partially occupied for the pristine and Si - doped NaZr .',
#   'Moreover , according to these coordination polyhedra , we can partition the NaZr .',
#   'The average site occupancies of the different Na sites show that all the Na sites are partially occupied for the pristine and Si - doped NaZr .'],
#  'Na ions migrate in this geometric': ['It was rationally assumed that all Na ions migrate in this geometric space .',
#   'It was rationally assumed that all Na ions migrate in this geometric space .'],
#  'Na ,': ['These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .'],
#  'Na –': ['These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .',
#   'Since the Na – Na – Na – Na – Na channel is more favorable than the Na – Na – Na – Na channel for Na + ion conduction , a rhombohedral NASICON - type material with a larger Na – Na – Na – Na – Na channel will have a higher ion conductivity .'],
#  'Na , and': ['These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'It has been previously noted that the intercalation chemistry of Ca ions is so different from that of Li , Na , and Mg that designing an Ca cathode using the analogies and parallelism between them is not possible , despite the prediction of some high - energy Ca cathode materials by theoretical calculations .',
#   'These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'It has been previously noted that the intercalation chemistry of Ca ions is so different from that of Li , Na , and Mg that designing an Ca cathode using the analogies and parallelism between them is not possible , despite the prediction of some high - energy Ca cathode materials by theoretical calculations .'],
#  'Na .': ['These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'Moreover , the Na + ions are more likely to stay at the Na site for NaZr , while for Na . ZrSi . P . O they have to occupy both Na and Na sites because there are not enough Na sites for all Na ions and a lot of available Na sites for the extra Na + ions .',
#   'These two conduction pathways consist of three elementary segments Na – Na , Na – Na , and Na – Na .',
#   'Moreover , the Na + ions are more likely to stay at the Na site for NaZr , while for Na . ZrSi . P . O they have to occupy both Na and Na sites because there are not enough Na sites for all Na ions and a lot of available Na sites for the extra Na + ions .'],
#  'O− ions in the PO': ['Moreover , as can be seen in Figure d , e , there are three distinct bottleneck areas : one is in the These bottlenecks are formed by three O− ions in the PO tetrahedron and ZrO octahedron pockets .',
#   'Moreover , as can be seen in Figure d , e , there are three distinct bottleneck areas : one is in the These bottlenecks are formed by three O− ions in the PO tetrahedron and ZrO octahedron pockets .'],
#  'NaZr located in Na – Na': ['For NaZr located in Na – Na segment .',
#   'For NaZr located in Na – Na segment .'],
#  '+ ion conduction in the Na – - Na – Na – Na – Na': ['As a consequence , the bottleneck B is likely the limiting factor for Na + ion conduction in the Na – - Na – Na – Na – Na channel .',
#   'As a consequence , the bottleneck B is likely the limiting factor for Na + ion conduction in the Na – - Na – Na – Na – Na channel .'],
#  'O− and': ['However , the size of bottleneck B is slightly smaller than the sum of the O− and Na + radii which needs to be further tailored .',
#   'However , the size of bottleneck B is slightly smaller than the sum of the O− and Na + radii which needs to be further tailored .'],
#  '+': ['However , the size of bottleneck B is slightly smaller than the sum of the O− and Na + radii which needs to be further tailored .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .',
#   'However , the size of bottleneck B is slightly smaller than the sum of the O− and Na + radii which needs to be further tailored .',
#   'Additionally , when increasing the Na + concentration , more Na + ions tend to occupy the high energy Na site and the number of Na + configurations of “ Na + Na + Va ” increases , which further facilitates the concerted migration , decreases the overall activation energy and thus promotes the mobility of Na + ions .'],
#  '+ ion conduction is likely highly dependent on whether the central': ['For the Na – Na – Na – Na channel and the local channels around Na site , Na + ion conduction is likely highly dependent on whether the central Na site is occupied or not .',
#   'For the Na – Na – Na – Na channel and the local channels around Na site , Na + ion conduction is likely highly dependent on whether the central Na site is occupied or not .'],
#  '+ at': ['If Na site is empty , the Na + at Na might tend to migrate to Na site through the Na – Na segment because the size of the bottleneck A .',
#   'If Na site is empty , the Na + at Na might tend to migrate to Na site through the Na – Na segment because the size of the bottleneck A .'],
#  'Na might tend to migrate to Na': ['If Na site is empty , the Na + at Na might tend to migrate to Na site through the Na – Na segment because the size of the bottleneck A .',
#   'If Na site is empty , the Na + at Na might tend to migrate to Na site through the Na – Na segment because the size of the bottleneck A .'],
#  '+ ions under conditions , we also performed AIMD': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .'],
#  'Si - doped': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'The average site occupancies of the different Na sites show that all the Na sites are partially occupied for the pristine and Si - doped NaZr .',
#   'The Na + ion dynamics of the pristine and Si - doped NaZr were calculated using AIMD simulations .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'The average site occupancies of the different Na sites show that all the Na sites are partially occupied for the pristine and Si - doped NaZr .',
#   'The Na + ion dynamics of the pristine and Si - doped NaZr were calculated using AIMD simulations .'],
#  'NaZr , i . e . ,': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .'],
#  'NaZrPO and': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .'],
#  'NaZrPSiO , with': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .'],
#  'atoms and': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .'],
#  'atoms , respectively .': ['To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .',
#   'To further uncover the preferential migration channel for Na + ions under dynamic conditions , we also performed AIMD simulations on an extended cell containing eight formula units of the pristine and Si - doped NaZr , i . e . , NaZrPO and NaZrPSiO , with atoms and atoms , respectively .'],
#  '+ ion conduction .': ['As the Na – Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , while the Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , the difference of the Na – Na and Na – Na segments play the important role in the preference of Na + ion conduction .',
#   'As the Na – Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , while the Na – Na – Na – Na channel has the segments of Na – Na and Na – Na , the difference of the Na – Na and Na – Na segments play the important role in the preference of Na + ion conduction .'],
#  'Na – Na channel are predominant .': ['As can be seen , the jump events in Na – Na channel are very rare , while the jump events in Na – Na channel are predominant .',
#   'As can be seen , the jump events in Na – Na channel are very rare , while the jump events in Na – Na channel are predominant .'],
#  'K , as shown in Table S .': ['The same behavior is confirmed for all the used simulation temperatures ranging from to K , as shown in Table S .',
#   'The same behavior is confirmed for all the used simulation temperatures ranging from to K , as shown in Table S .'],
#  '+ ions prefer to migrate through the': ['These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .'],
#  'Na – Na – Na': ['These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
#   'These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .'],
#  'Na – Na – Na – Na': ['These results indicate that Na + ions prefer to migrate through the Na – Na – Na – Na – Na channels rather than through the Na – Na – Na – Na channels which is consistent with the static bottleneck analysis above .',
# ...
#   'The evidence of Ca insertion into NaVP by means of the chemical reduction does not provide enough proof for the reversibility of the Ca insertion , which can be verified more evidently via electrochemical cycling .'],
#  'calcium ions are inserted into the': ['On discharge , the anions in the electrolyte are adsorbed on the surface of the AC counter electrode and calcium ions are inserted into the cathode .',
#   'On discharge , the anions in the electrolyte are adsorbed on the surface of the AC counter electrode and calcium ions are inserted into the cathode .'],
#  'Ca storage may change during the cycles .': ['The first few cycles of discharge - charge plateau voltages are lower than those of the following cycles , indicating that the electrochemical reactions for Ca storage may change during the cycles .',
#   'The first few cycles of discharge - charge plateau voltages are lower than those of the following cycles , indicating that the electrochemical reactions for Ca storage may change during the cycles .'],
#  'Na in NaVP is irreversibly exchanged with': ['ICP elemental analysis revealed the Na in NaVP is irreversibly exchanged with Ca during the initial discharge - charge cycles , the detailed evidence of which will be discussed later .',
#   'ICP elemental analysis revealed the Na in NaVP is irreversibly exchanged with Ca during the initial discharge - charge cycles , the detailed evidence of which will be discussed later .'],
#  'Ca during the initial discharge': ['ICP elemental analysis revealed the Na in NaVP is irreversibly exchanged with Ca during the initial discharge - charge cycles , the detailed evidence of which will be discussed later .',
#   'ICP elemental analysis revealed the Na in NaVP is irreversibly exchanged with Ca during the initial discharge - charge cycles , the detailed evidence of which will be discussed later .'],
#  'g− , which matched the last discharge': ['The initial charge capacity was mAh g− , which matched the last discharge capacity at degree C . However , in the subsequent cycle , the capacity was reduced to mAh g− , with increased polarization .',
#   'The initial charge capacity was mAh g− , which matched the last discharge capacity at degree C . However , in the subsequent cycle , the capacity was reduced to mAh g− , with increased polarization .'],
#  'g− , with increased polarization .': ['The initial charge capacity was mAh g− , which matched the last discharge capacity at degree C . However , in the subsequent cycle , the capacity was reduced to mAh g− , with increased polarization .',
#   'The initial charge capacity was mAh g− , which matched the last discharge capacity at degree C . However , in the subsequent cycle , the capacity was reduced to mAh g− , with increased polarization .'],
#  '~ mAh g− and was maintained .': ['The capacity decreased slowly for several subsequent cycles , but gradually increased back to ~ mAh g− and was maintained .',
#   'The capacity decreased slowly for several subsequent cycles , but gradually increased back to ~ mAh g− and was maintained .'],
#  'Ca insertion / extraction , in good agreement with the dQ /': ['The redox peaks clearly indicate reversible Ca insertion / extraction , in good agreement with the dQ / dV plots in Figure S .',
#   'The redox peaks clearly indicate reversible Ca insertion / extraction , in good agreement with the dQ / dV plots in Figure S .'],
#  'Ca anode': ['However , only for comparison purposes with other materials , the energy density was estimated based on the Ca anode potential .',
#   'However , only for comparison purposes with other materials , the energy density was estimated based on the Ca anode potential .'],
#  'Wh kg− .': ['The energy density of NaVP is about Wh kg− .',
#   'The energy density of NaVP is about Wh kg− .'],
#  'Li': ['It is still less than that of the state - of - the - art Li - ion cathode material LiCoO .',
#   'It is still less than that of the state - of - the - art Li - ion cathode material LiCoO .'],
#  'LiCoO .': ['It is still less than that of the state - of - the - art Li - ion cathode material LiCoO .',
#   'It is still less than that of the state - of - the - art Li - ion cathode material LiCoO .'],
#  'Ca insertion , as in the chemical': ['After discharge , peaks were shifted to a lower angle , indicating an increase of the cell parameters due to the Ca insertion , as in the chemical calciation case Ca . NaVP .',
#   'After discharge , peaks were shifted to a lower angle , indicating an increase of the cell parameters due to the Ca insertion , as in the chemical calciation case Ca . NaVP .'],
#  'Ca . NaVP .': ['After discharge , peaks were shifted to a lower angle , indicating an increase of the cell parameters due to the Ca insertion , as in the chemical calciation case Ca . NaVP .',
#   'After discharge , peaks were shifted to a lower angle , indicating an increase of the cell parameters due to the Ca insertion , as in the chemical calciation case Ca . NaVP .'],
#  'Ca insertion': ['Such changes were also observed at the th cycle , demonstrating excellent Ca insertion - extraction reversibility .',
#   'Such changes were also observed at the th cycle , demonstrating excellent Ca insertion - extraction reversibility .'],
#  'CaF byproduct , as previously reported for other': ['However , in contrast to chemical calciation , an impurity phase was observed for the cycled electrode due to the formation of CaF byproduct , as previously reported for other cathode materials using Ca - based electrolyte .',
#   'However , in contrast to chemical calciation , an impurity phase was observed for the cycled electrode due to the formation of CaF byproduct , as previously reported for other cathode materials using Ca - based electrolyte .'],
#  'CaF might contribute to the total capacity , however its portion should be insignificant , considering the high reversibility of the discharge /': ['It should be emphasized that the formation of CaF might contribute to the total capacity , however its portion should be insignificant , considering the high reversibility of the discharge / charge reaction .',
#   'It should be emphasized that the formation of CaF might contribute to the total capacity , however its portion should be insignificant , considering the high reversibility of the discharge / charge reaction .'],
#  'Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange': ['The results suggest that Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange reaction between Na and Ca ions occurs during the cycle .',
#   'The results suggest that Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange reaction between Na and Ca ions occurs during the cycle .'],
#  'Na and': ['The results suggest that Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange reaction between Na and Ca ions occurs during the cycle .',
#   'The elemental analyses showed that such an additional Na extraction seemed irreversible ; thus , the subsequent Ca insertion resulted in the effect of exchange between Na and Ca ions , which reasonably explains the exchange mechanism .',
#   'The existence of the activation cycles suggests that the exchange between Na and Ca ions cannot be completed in the first cycle but needs several cycles even at high temperature .',
#   'This intercalation mechanism may also explain how the exchange reaction takes place between Na and Ca ions during the initial activation cycles .',
#   'The results suggest that Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange reaction between Na and Ca ions occurs during the cycle .',
#   'The elemental analyses showed that such an additional Na extraction seemed irreversible ; thus , the subsequent Ca insertion resulted in the effect of exchange between Na and Ca ions , which reasonably explains the exchange mechanism .',
#   'The existence of the activation cycles suggests that the exchange between Na and Ca ions cannot be completed in the first cycle but needs several cycles even at high temperature .',
#   'This intercalation mechanism may also explain how the exchange reaction takes place between Na and Ca ions during the initial activation cycles .'],
#  'Ca ions occurs during the cycle .': ['The results suggest that Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange reaction between Na and Ca ions occurs during the cycle .',
#   'The results suggest that Na ions are preferentially extracted from the CaxNaVP phase , implying that an exchange reaction between Na and Ca ions occurs during the cycle .'],
#  'Ca . NaVP ,': ['The additional Na extraction from NaVP when NaVP is reduced to Ca . NaVP , Na ions in the b site migrate back to the e site and Ca ions are preferentially inserted into the b site .',
#   'The additional Na extraction from NaVP when NaVP is reduced to Ca . NaVP , Na ions in the b site migrate back to the e site and Ca ions are preferentially inserted into the b site .'],
#  'Ca ions are preferentially inserted into the b': ['The additional Na extraction from NaVP when NaVP is reduced to Ca . NaVP , Na ions in the b site migrate back to the e site and Ca ions are preferentially inserted into the b site .',
#   'Structural investigations suggested that Na ions are preferentially extracted from the e site , Ca ions are preferentially inserted into the b site of the NASICON structure , and that the Na ions in the structure can migrate between the two sites during a cycle .',
#   'The additional Na extraction from NaVP when NaVP is reduced to Ca . NaVP , Na ions in the b site migrate back to the e site and Ca ions are preferentially inserted into the b site .',
#   'Structural investigations suggested that Na ions are preferentially extracted from the e site , Ca ions are preferentially inserted into the b site of the NASICON structure , and that the Na ions in the structure can migrate between the two sites during a cycle .'],
#  'carrier ions .': ['This mechanism matches well with the three - dimensional diffusion pathways in Figure b , which indicated that each of the b sites is connected to six e sites , playing a role as the hub of the carrier ions .',
#   'This mechanism matches well with the three - dimensional diffusion pathways in Figure b , which indicated that each of the b sites is connected to six e sites , playing a role as the hub of the carrier ions .'],
#  'Na ions in the e': ['If a similar oxidation mechanism is applied to CaxNaVP , Na ions in the e site are likely to be extracted preferentially .',
#   'If a similar oxidation mechanism is applied to CaxNaVP , Na ions in the e site are likely to be extracted preferentially .'],
#  'Ca insertion resulted in the effect of exchange between': ['The elemental analyses showed that such an additional Na extraction seemed irreversible ; thus , the subsequent Ca insertion resulted in the effect of exchange between Na and Ca ions , which reasonably explains the exchange mechanism .',
#   'The elemental analyses showed that such an additional Na extraction seemed irreversible ; thus , the subsequent Ca insertion resulted in the effect of exchange between Na and Ca ions , which reasonably explains the exchange mechanism .'],
#  'Ca ions , which reasonably explains the exchange': ['The elemental analyses showed that such an additional Na extraction seemed irreversible ; thus , the subsequent Ca insertion resulted in the effect of exchange between Na and Ca ions , which reasonably explains the exchange mechanism .',
#   'The elemental analyses showed that such an additional Na extraction seemed irreversible ; thus , the subsequent Ca insertion resulted in the effect of exchange between Na and Ca ions , which reasonably explains the exchange mechanism .'],
#  'Ca ions cannot be completed in the first cycle but needs several cycles even at temperature .': ['The existence of the activation cycles suggests that the exchange between Na and Ca ions cannot be completed in the first cycle but needs several cycles even at high temperature .',
#   'The existence of the activation cycles suggests that the exchange between Na and Ca ions cannot be completed in the first cycle but needs several cycles even at high temperature .'],
#  'Ca insertion into NASICON': ['In summary , the chemical , electrochemical , and structural investigations corroborated the capability of reversible Ca insertion into NASICON - type NaV , which can be a potential cathode material for CIBs with a high energy density : ~ Wh kg− and about ~ Wh kg− are estimated at degree C and degree C , respectively , if Ca metal anode can be used .',
#   'In summary , the chemical , electrochemical , and structural investigations corroborated the capability of reversible Ca insertion into NASICON - type NaV , which can be a potential cathode material for CIBs with a high energy density : ~ Wh kg− and about ~ Wh kg− are estimated at degree C and degree C , respectively , if Ca metal anode can be used .'],
#  'mAh g− at .': ['At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .',
#   'At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .'],
#  'mA g− with an average discharge': ['At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .',
#   'At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .'],
#  '~': ['At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .',
#   'At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .'],
#  'V after initial activation .': ['At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .',
#   'At degree C , the discharge capacity was mAh g− at . mA g− with an average discharge voltage of ~ . V after initial activation .'],
#  'Na ions are preferentially extracted from the e': ['Structural investigations suggested that Na ions are preferentially extracted from the e site , Ca ions are preferentially inserted into the b site of the NASICON structure , and that the Na ions in the structure can migrate between the two sites during a cycle .',
#   'Structural investigations suggested that Na ions are preferentially extracted from the e site , Ca ions are preferentially inserted into the b site of the NASICON structure , and that the Na ions in the structure can migrate between the two sites during a cycle .'],
#  'Na ions in the structure can migrate between the two sites during a cycle .': ['Structural investigations suggested that Na ions are preferentially extracted from the e site , Ca ions are preferentially inserted into the b site of the NASICON structure , and that the Na ions in the structure can migrate between the two sites during a cycle .',
#   'Structural investigations suggested that Na ions are preferentially extracted from the e site , Ca ions are preferentially inserted into the b site of the NASICON structure , and that the Na ions in the structure can migrate between the two sites during a cycle .'],
#  'Ca ions during the initial': ['This intercalation mechanism may also explain how the exchange reaction takes place between Na and Ca ions during the initial activation cycles .',
#   'This intercalation mechanism may also explain how the exchange reaction takes place between Na and Ca ions during the initial activation cycles .']}

# %%
save_result = []

for k in knowledge.keys():
    for key, value in knowledge[k].items():
        for i in range(len(value)):
            save_result.append([key + " (" + k + ")", value[i]])
            
df_new_base = pd.DataFrame(save_result)
df_new_base.to_excel("./lyz_knowledge_base_with_tag.xlsx", encoding='utf-8', index=False, header=False)
