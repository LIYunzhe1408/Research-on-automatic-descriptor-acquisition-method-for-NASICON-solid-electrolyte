# %%
import re
import pandas as pd
import enchant

d = enchant.Dict("en_US")

# %%
raw_ner_result = pd.read_csv('./add_knowledge_base.csv', header=None, encoding='utf-8')

# %%
raw_ner_result[:100]
# Out:
#     0                                                  1
# 0   M  © Pleiades Publishing , New phosphates with th...
# 1   M  M . phates were synthesized by the Pechini pro...
# 2   M  In each phosphate series , the а cell paramete...
# 3   M  The molarity of LiOH and LiCl in the LiOH and ...
# 4   M  The solubility limit of LiOH in water is about...
# .. ..                                                ...
# 95  M  From the dependence of CQ versus temperature ,...
# 96  M  Preparation , characterization and conductivit...
# 97  M  Abstract : Nasicon type compounds of general f...
# 98  M  In this structure , the partial substitution o...
# 99  M  The purpose of this work is to substitute the ...
#
# [100 rows x 2 columns]

# %%
filter_list = []
for i in range(len(raw_ner_result)):
    now_word_list = str(raw_ner_result.iloc[i, 0]).split(" ")
    
    count = 0
    for j in range(len(now_word_list)):
        if d.check(now_word_list[j]):
            count += 1
                
    if count == len(now_word_list):
        filter_list.append([raw_ner_result.iloc[i, 0], raw_ner_result.iloc[i, 1]])

# %%
len(filter_list)
# Out:
# 349089

# %%
df_list = []
for ele in filter_list:
    if ele[0] in df_list:
        continue
    else:
        df_list.append(ele[0])

# %%
df = pd.DataFrame(df_list)
df.to_csv("./material_knowledge.csv", header=None, index=None, encoding='utf-8')

# %%
filter_list_df = pd.DataFrame(filter_list)

# %%
filter_list_df
# Out:
#                                0  \
# 0                              M
# 1                              M
# 2                              M
# 3                              M
# 4                              M
# ...                          ...
# 349084  oxygen partial pressures
# 349085                   October
# 349086               K structure
# 349087                yeast cell
# 349088        special atmosphere
#
#                                                         1
# 0       © Pleiades Publishing , New phosphates with th...
# 1       M . phates were synthesized by the Pechini pro...
# 2       In each phosphate series , the а cell paramete...
# 3       The molarity of LiOH and LiCl in the LiOH and ...
# 4       The solubility limit of LiOH in water is about...
# ...                                                   ...
# 349084  The ± % praseodymium ion in the composites was...
# 349085  Ana Martı´nez - Jua´rez , Carlos Pecharroma´n ...
# 349086  shows the adsorption – desorption isotherm and...
# 349087  The band at cm− is caused by the C \ O stretch...
# 349088  Finally , the sample is calcinated at °C in th...
#
# [349089 rows x 2 columns]

# %%
merge_entity = {}

# %%
for i in range(len(filter_list_df)):
    now_sent = str(filter_list_df.iloc[i, 1]).split(" ")
    old_len = len(now_sent)
    last_word = now_sent.pop()
    new_len = len(now_sent)
    assert old_len-1 == new_len
    
    
    if last_word != "." or "." in now_sent or new_len <= 8:
        continue
    
    if filter_list_df.iloc[i, 1] not in merge_entity:
        merge_entity[filter_list_df.iloc[i, 1]] = [filter_list_df.iloc[i, 0]]
    else:
        merge_entity[filter_list_df.iloc[i, 1]].append(filter_list_df.iloc[i, 0])

# %%
len(merge_entity)
# Out:
# 86987

# %%
merge_entity
# Out:
# {'In each phosphate series , the а cell parameter increases slightly when the M + cations occupy vacant sites ( Fig .': ['M',
#   'sites',
#   'cell parameter',
#   'phosphate'],
#  'The solubility limit of LiOH in water is about M at room temperature .': ['M',
#   'solubility',
#   'room temperature'],
#  'The solubility of LiOH decreases with increasing content of LiCl in LiCl – LiOH – HO to about M , and then turns into increase .': ['M',
#   'HO',
#   'content',
#   'solubility'],
#  'The impedance proﬁle of the LTAP plate immersed in saturated LiNO – M LiOH – HO at [UNK] for weeks is also shown in Fig .': ['M',
#   'HO',
#   'weeks'],
#  'The - butanoldehydrogenation selectivity increases linearly withincreasing standard reduction potential of ion M .': ['M',
#   'reduction potential'],
#  'M and M positions alternate along three - dimensional conduction channels .': ['M',
#   'M positions',
#   'three'],
#  'Therhombohedral LiTi ] rigid framework that provides two different sites , labeled M andM , for Lithium ion conduction .': ['M',
#   'Lithium ion',
#   'sites',
#   'conduction'],
#  'Thus , we are led to conclude that the lithium ions in LiHf are significantly delocalized between the M and M centers even at room temperature , which indicates that they have high mobility .': ['M',
#   'lithium ions',
#   'M centers',
#   'high mobility',
#   'room temperature'],
#  'This matrix can be an electronic conductive metal , M , or ionic conductive materials such as LiO and LiS .': ['M',
#   'ionic conductive materials'],
#  'The electrode materials in coin cells were assembled with M LiPF in EC : DMC as the electrolyte .': ['M',
#   'coin cells',
#   'electrolyte',
#   'electrode materials',
#   'EC'],
#  'The electrolyte was M LiPF , which was dissolved in a diethyl carbonate .': ['M',
#   'electrolyte'],
#  'Here , we have synthesized and characterizedcomplex titanium phosphates of composition with M = Mg , Ca , Sr , or Ba , investigated their phase - formation laws , determined thestructure types in which they crystallize , and determinedtheir concentration and temperature stabilityfields .': ['M',
#   'composition',
#   'Mg',
#   'Ca',
#   'Ba',
#   'Sr',
#   'phase',
#   'concentration',
#   'titanium phosphates'],
#  'to the eye , parallel In the NASICON - type structure compounds , there are two different interstitial sites , M and M .': ['M',
#   'M',
#   'interstitial sites'],
#  'The ionic conductivity is strongly affected by the content of partially occupied M and the size of the bottleneck through which the conducting ions migrate .': ['M',
#   'conducting ions',
#   'bottleneck',
#   'ionic conductivity',
#   'content'],
#  'The resultant electrochemical cells were assembled in a glove box ﬁlled with high - purity argon where pure sodium foil , M NaClO in propylene carbonate and glass ﬁber were used as the counter electrode , the electrolyte and the separator , respectively .': ['M',
#   'propylene carbonate',
#   'sodium foil',
#   'electrolyte',
#   'separator',
#   'electrochemical cells',
#   'counter electrode'],
#  'Their general formula is AMM P O where ‘ A ’ can be alkali , alkaline earth or Cuq ion , M and MX can be tri - , tetraor pentavalent transition metal ion .': ['M',
#   'alkali',
#   'alkaline earth',
#   'transition metal ion'],
#  'A systematic increase in a parameter with sintering treatment is observed which may be probably due to differences in lithium disposition within M and M cavities .': ['M',
#   'M',
#   'cavities',
#   'parameter',
#   'sintering treatment'],
#  'Spectra of the dielectric modulus , M ” showing the dc conductivity relaxation .': ['M',
#   'dielectric modulus',
#   'dc conductivity relaxation'],
#  'Assuming that a Na - Cs ‖ NaI hybrid flow battery is made of a NaCs anode and an aqueous NaI catholyte with a NaI concentration at M of the state - of - the - art VRBs .': ['M',
#   'Na',
#   'Cs'],
#  'When M is Mn and M is Fe in NaxM [ M , a higher content of Na can be achieved .': ['M',
#   'M',
#   'M',
#   'Na',
#   'Fe',
#   'Mn',
#   'higher content'],
#  'Within the Nasicon framework , there are interconnected interstitial sites usually labelled M through which A cation can diffuse , giving rise to a fast - ion conductivity .': ['M',
#   'A cation',
#   'interstitial sites',
#   'fast',
#   'ion conductivity'],
#  'They are mixed valent oxides with M + / M + = / .': ['M', 'M'],
#  "By the shift between configuration I , Li approaches both the M ' and M ' ' neighboring sites , so as to come nearer to the straight line connecting them and thus to be in a more favorable position for hopping along the mobility pathway .": ['M',
#   'M',
#   'Li',
#   'sites',
#   'mobility pathway',
#   'hopping'],
#  'In the passage from configuration I to II , Li gets closer to O and farther from the O ′ ′ oxygen atom , consistent with the shift toward the M ′ - M ′ ′ line .': ['M',
#   'Li',
#   'O',
#   'O'],
#  'link between the Fe octahedra that forms the [ M , which we will refer to as a double lantern unit ( Fig .': ['M',
#   'Fe octahedra',
#   'double lantern unit'],
#  'One of the most striking features of this structure is that the Li + ions lie in a new - fold coordinated site , different from the M .': ['M',
#   'Li',
#   'structure',
#   'new',
#   'fold coordinated site'],
#  'Two kind of interstitial sites are commonly named as M and M .': ['M',
#   'M',
#   'interstitial sites'],
#  'The increase of ionic radius of the M + cation induces an elongation of this octahedral site , involving an increase of the c axis .': ['M',
#   'octahedral site',
#   'c axis',
#   'ionic radius'],
#  'The NASICON - structured materials withthe formula unit of AxMy , where A , M and X are alkalimetal , transition metal and nonmetal atoms , respectively , canbe described as three - dimensional polyanionic frameworks ofcorner sharing MO octahedra and XO tetrahedra withinterconnected channels for the diffusion of alkali ions .': ['M',
#   'A',
#   'X',
#   'MO octahedra',
#   'transition metal',
#   'alkali ions',
#   'formula unit',
#   'nonmetal atoms'],
#  'From this figure , it is observed that the real part of modulus spectra , M ′ , exhibits dispersion as the frequency is increased and tends to saturate at M∞ at higher frequencies .': ['M',
#   'modulus spectra',
#   'higher frequencies'],
#  'The small value of M ′ in the low frequency region facilitates the migration of ion conduction .': ['M',
#   'ion conduction',
#   'migration'],
#  'The imaginary part of modulus spectra , M ″ , in Fig .': ['M'],
#  'shows a single relaxation peak focused at the dispersion region of M ′ .': ['M',
#   'single relaxation peak'],
#  'Figure exhibits a master plot of the modulus isotherms , where the frequency axis is scaled by the relaxation frequency fmax and M ′ .': ['M',
#   'frequency axis',
#   'modulus'],
#  'The scaled spectra of M ′ and M ″ for the present glass and its glass - ceramic nanocomposites at a fixed temperature are also shown in Fig .': ['M',
#   'scaled spectra',
#   'fixed temperature'],
#  'The possibility of varying the cationic composition within a single structural type enables one to perform the directed synthesis of variable composition phases M – хA – хR + х , which are isostructural to NASICON .': ['M',
#   'cationic composition',
#   'single structural type'],
#  'Li and P chemical shift values were given relative to M LiCl and % HPO aqueous solutions .': ['M',
#   'M',
#   'aqueous solutions',
#   'aqueous solutions',
#   'chemical shift',
#   'chemical shift'],
#  'From the dependence of CQ versus temperature , T the partial occupancy of midway M / sites at the expense of those of M was deduced at increasing temperatures .': ['M',
#   'occupancy',
#   'CQ',
#   'temperatures',
#   'temperature'],
#  'In the present series of compounds , the charge of the metal ion is same and therefore the polarizing power depends only on the ionic size of M + .': ['M',
#   'M',
#   'ionic size',
#   'ionic size',
#   'polarizing power',
#   'polarizing power',
#   'metal ion',
#   'metal ion'],
#  'Since the ionic size of M + follows the order Al + < Cr + < Fe + , the order of ν is expected to be LATP > LCTP > LFTP .': ['M',
#   'Al',
#   'ionic size'],
#  'Molybdates of trivalent metal ions M were found to accommodate lithium both chemically and electrochemically .': ['M',
#   'trivalent metal ions'],
#  'Nonaqueous M LiPF in EC / DMC solution was used as the electrolyte .': ['M',
#   'electrolyte',
#   'EC'],
#  'on NASICON - related framework compounds such as M and they reported that the redox potentials of the M cations are shifted due to the change in the polyanion group .': ['M',
#   'M cations'],
#  'The large possible composition spectrum involving [UNK] elements within the M and X positions was used by J .': ['M',
#   'composition',
#   'X positions',
#   'elements'],
#  'Two sheets of Whatman GF / D borosilicate glass ﬁber were used as the separator , soaked with M NaClO in propylene carbonate electrolyte .': ['M',
#   'separator',
#   'soaked',
#   'propylene carbonate electrolyte'],
#  'TiO octahedra are red , PO tetrahedra are blue , and sodium ions are distributed among two sites : M which are ordered in the triclinic cell .': ['M',
#   'sodium ions',
#   'sites',
#   'triclinic cell'],
#  'When the covalency between M – O is stronger , the energy splitting between antibonding and bonding orbitals will be larger , and the antibonding orbitals will be pushed up .': ['M',
#   'O',
#   'orbitals',
#   'energy splitting'],
#  'If X has stronger electronegativity than M , the covalency between MO will be lowered , which leads to higher Δ and hence higher voltage .': ['M',
#   'X',
#   'higher voltage'],
#  'The remaining two O atoms are abridged with SO tetrahedra , thereby forming M blocks with Na + occupying large voids .': ['M',
#   'Na',
#   'O atoms'],
#  'tain two crystallographic sites , M and M , for cations that compensate for the charge of the anion sublattice , which formula М .': ['M',
#   'M',
#   'cations',
#   'crystallographic sites'],
#  'The parameters in the above potential are charges on various ions M , Zr , P , or O .': ['M',
#   'Zr',
#   'P',
#   'O',
#   'potential',
#   'parameters'],
#  'Therefore , we have only changed the size of the ion , M .': ['M',
#   'ion',
#   'size'],
#  'A plot of the self diffusivities against M , the size parameter in the intermolecular potential , is shown in Figure .': ['M',
#   'size parameter',
#   'intermolecular potential'],
#  'Figure however differs from those found for atom diffusion in porous solids in that there is no regime where D , in which self diffusivity decreases linearly with increase in M .': ['M',
#   'D',
#   'diffusivity',
#   'atom diffusion',
#   'porous solids'],
#  'The Na + cations are accommodated within two distinct crystallographic sites , designated M and M , as described by the formula ] .': ['M',
#   'M',
#   'Na',
#   'crystallographic sites'],
#  'The Cu + cations in both CuZr , and the conduction pathway necessitates their movement through the inﬁnite sequence M – M – M – M – .': ['M',
#   'M',
#   'M',
#   'M',
#   'Cu',
#   'conduction pathway'],
#  'Since the distance of M – O on the M .': ['M', 'distance'],
#  'The precipitate was washed with mL deionized water to remove excess base and then dissolved in a M solution of oxalic acid ] was formed .': ['M',
#   'base',
#   'precipitate'],
#  'A glass fiber membrane served as the separator , and M NaPF in a mixture of ethylene carbonate was used as the electrolyte .': ['M',
#   'ethylene carbonate',
#   'glass fiber membrane',
#   'electrolyte'],
#  'The electrochemical behaviors of the NTP nanoparticles and NTP⊂GN were evaluated using coin - type cells with sodium metal as counter electrode and with M NaClO in ethylene carbonate as electrolyte .': ['M',
#   'ethylene carbonate',
#   'electrochemical behaviors',
#   'sodium metal',
#   'electrolyte',
#   'electrode',
#   'counter'],
#  'NASICON , where M is a transition metal , have attracted a considerable attentionbecause of their high ionic conductivity and the possibility of tuning the operation voltageby changing M .': ['M',
#   'M',
#   'ionic conductivity',
#   'transition metal'],
#  'After submerged in M LiPF liquid electrolyte solution for min until equilibrium was achieved and then weighted as W .': ['M',
#   'W',
#   'electrolyte solution'],
#  'The heights of M obtained from theexperimental plots are close to that of Mmax = C / C , confirming the Debye nature of thesesamples .': ['M',
#   'heights'],
#  'Compounds with the formula LiMPO with M = Ge , Ti , Sn , Zr , and Hf have been extensively studied fortheir ionic conductivity and thermal expansion behavior .': ['M',
#   'Ti',
#   'Zr',
#   'Ge',
#   'Hf',
#   'Sn',
#   'ionic conductivity',
#   'thermal expansion behavior'],
#  'The cations M occupy two types of sites in the structure with different oxygen environments , referred to as M and M .': ['M',
#   'M',
#   'M',
#   'cations',
#   'sites',
#   'oxygen environments'],
#  'The distribution of M between these sites is believed to depend on the nature of the cation M and perhaps also on the factors governing the method of preparation .': ['M',
#   'cation M',
#   'sites'],
#  'Other compounds belonging to the same family M Hf .': ['M',
#   'Hf',
#   'compounds'],
#  'It can be assumed then that the situation is probably analogous for the isostructural phosphates M Hf .': ['M',
#   'Hf'],
#  'The mechanism has been proved by the groups of Dahn and Huggins in the tin - based compounds where the MX will form an inactive amorphous LiX matrix and nano electroactive M particles by electrochemical reduction during the first discharge .': ['M',
#   'electrochemical reduction'],
#  'b that the value of M decreases and shifts toward higher frequencies as temperature increases .': ['M',
#   'temperature'],
#  'The shift in frequency of the M peak corresponds to the conductivity relaxation phenomenon .': ['M',
#   'conductivity relaxation phenomenon'],
#  'The two sites for Li + ions are represented as follows : M by open circles , and M by closed circles .': ['M',
#   'M',
#   'M',
#   'M',
#   'Li',
#   'Li',
#   'sites',
#   'sites'],
#  'The charge of the anionic framework is compensated for by cations : Na + ions that can occupy two positions , M and M , in a channel .': ['M',
#   'M',
#   'Na',
#   'channel',
#   'anionic framework',
#   'cations'],
#  'At ~ °C , M is completely populated , and M is free .': ['M', 'M'],
#  'b are associated with the transition of sodium ions from M into M , as are the unit cell parameters .': ['M',
#   'M',
#   'sodium ions',
#   'unit cell parameters',
#   'transition'],
#  'After the discovery of the M were also developed .': ['M'],
#  'The Nasicon framework is described as an isolated tetrahedra sub lattice , where the M , M cations ﬁll cavities between tetrahedra .': ['M',
#   'M cations',
#   'lattice'],
#  'EXAFS studies of Cu ? M , Ax x ¼ : ; A ¼ H Þ Cuþ studies of Cuþ Þ and Cuþ Þ were studied by Fargin et al .': ['M',
#   'Cu'],
#  'characterization of Mþ Copper containing Nasicons , Cu ? M or Cuþ : M Þ with tetravalent M ions occupying the Nasicon ð PO framework have been studied .': ['M',
#   'Cu',
#   'PO',
#   'M ions',
#   'Copper',
#   'tetravalent'],
#  'Preparation and selective catalytic oxidation of hydrocarbons using M ? TiPO as catalysts are reported by Oudet et al .': ['M',
#   'catalytic oxidation',
#   'Preparation',
#   'hydrocarbons',
#   'catalysts'],
#  'is observed that partial occupancy of M are found to occupy M sites .': ['M',
#   'M sites',
#   'occupancy'],
#  'In this compound , M site is empty and M is completely occupied , to ATi where the M is fully occupied by A ions and M is vacant .': ['M',
#   'M',
#   'M',
#   'A ions',
#   'M site'],
#  'The possibility of varying the cation compositionwithout changes in structure type allows for the targeted synthesis of M – хA – хR + х crystallizing inNASICONrelated structures .': ['M',
#   'cation'],
#  'A number of A x å compounds containing In + , Sc + , Fe + , Zr + , Hf + , Ti + , and Sn + cations in the position M have been studied .': ['M',
#   'Ti',
#   'Zr',
#   'Hf',
#   'Fe',
#   'Sc',
#   'position'],
#  'The electrolyte was a mixture of ethylene carbonate and dimethyl carbonate at a volume ratio of : with the addition of M NaClO .': ['M',
#   'ethylene carbonate',
#   'volume ratio',
#   'electrolyte'],
#  'A progressive transfer of Na + ions from the M .': ['M', 'Na'],
#  'Removal of Na + from M results in a strong increase of the c parameter due to stronger repulsions between adjacent FeO octahedral faces along .': ['M',
#   'Na',
#   'c parameter',
#   'repulsions'],
#  'The point symmetry of M is ; it is - coordinated and lies at the same z value as the phosphorus atom .': ['M',
#   'M',
#   'phosphorus atom',
#   'phosphorus atom',
#   'point symmetry',
#   'point symmetry'],
#  'Evolution of the NASICON framework distortion with the occupancy of the M .': ['M',
#   'occupancy'],
#  'The M but that should be differentiated in respect to further discussion on Li location in the structure .': ['M',
#   'structure',
#   'Li location'],
#  'M NaClO / ethylene carbonate was used as the electrolyte .': ['M',
#   'ethylene carbonate',
#   'electrolyte'],
#  'The effect of the anisotropic changes in lattice parameters on the distribution of M between the alkali ions calculated over the MC steps at K ( shown in Fig .': ['M',
#   'K',
#   'MC',
#   'lattice parameters',
#   'anisotropic',
#   'alkali ions'],
#  'This results in the splitting of the second peaks of the M – M rdfs ( Fig .': ['M'],
#  'The agreement in the positions of the peaks in the M – M rdfs for the simulated Na and Cs - systems to the M distances from their respective X - ray structures , shown by vertical lines in Fig .': ['M',
#   'M',
#   'Na',
#   'Cs',
#   'M distances',
#   'X',
#   'ray'],
#  'ZrO around an M , and the O - oxygens forms the basal planes of two neighbouring ZrO pillared by the edges of three PO tetrahedra when viewed along the c - axis .': ['M',
#   'axis'],
#  'Since the height of the M equals half the height of the lantern units its expands correspondingly .': ['M'],
#  'The proton conductivity of the simple perovskite Sr is in the M + doped SrCeO and BaCeO region .': ['M',
#   'proton conductivity',
#   'simple'],
#  'Recently , M - type structure is a quasi - layered structure and has a large pathway where M + ion can migrate smoothly , and the hexavalent tungsten ion bonds to four surrounding oxide anions to form a rigid WO tetrahedral unit .': ['M',
#   'oxide anions',
#   'tungsten ion bonds',
#   'M',
#   'quasi',
#   'layered structure',
#   'WO tetrahedral unit'],
#  'This results in a considerable reduction of the electrostatic interaction between M + and Oand the realization of the M + ion conduction .': ['M',
#   'M',
#   'conduction',
#   'electrostatic interaction'],
#  'The Sc - type structure has a quasilayered one and a large pathway where M + ion can migrate smoothly as shown in Figure .': ['M',
#   'pathway'],
#  'tion of the electrostatic interaction between M + andOand the realization of the M + ion conduction .': ['M',
#   'M',
#   'conduction',
#   'electrostatic interaction'],
#  'Therefore , M + cannot migrate in a Eu - type lattice due to the stronger electrostatic interaction with eight oxide anions .': ['M',
#   'oxide anions',
#   'electrostatic interaction'],
#  'In solid electrolytes with trivalent M + ion larger than Sc + , the conductivity decreases because the conducting M + cation size becomes disproportionately large compared with the lattice size .': ['M',
#   'Sc',
#   'conductivity',
#   'M',
#   'lattice size',
#   'solid electrolytes'],
#  'M + ionic radius dependencies of the electrical conductivity at °C for the tungstates - type structure .': ['M',
#   'ionic radius',
#   'electrical conductivity'],
#  'These advantages include high thermal stability , long distances between M + ions and adjustable chemical composition .': ['M',
#   'chemical composition',
#   'distances',
#   'high thermal stability'],
#  'The stretching and bending vibrations of the AsO - units and external modes , as well as the Zr + and M + .': ['M',
#   'Zr',
#   'stretching',
#   'external modes',
#   'bending vibrations'],
#  'The correlations between the spectra and the nature of the M + cation are revealed .': ['M',
#   'spectra'],
#  'Structure of Nasicon compounds displaying M , M , M , and M Li sites along conduction channels .': ['M',
#   'M',
#   'M',
#   'M',
#   'Li sites',
#   'conduction channels'],
#  'New negative peaks were detected for Li at M .': ['M', 'Li'],
#  'T The electrolyte was M of NaPF in diethylene glycol dimethyl ether .': ['M',
#   'T',
#   'electrolyte'],
#  'In addition , relaxation nature of M ″ data of all these glass – ceramic samples holds good the KWW function .': ['M'],
#  'Thus , the site potentials of M and M get close to each other by Ca doping .': ['M',
#   'M',
#   'site potentials',
#   'doping'],
#  'They crystallize in the space group Rhc , with the sodium ions being located in the M .': ['M',
#   'sodium ions'],
#  'It is well - established that the value of the a - parameter is strongly correlated to the following : the size of the M and M¢ cations of the [ MM¢ .': ['M',
#   'a',
#   'parameter',
#   'size'],
#  'reported a series of NASICON - structured NaxMV compounds with half of the V in NVP being substituted , in which M represents Mn , Fe , and Ni .': ['M',
#   'Ni',
#   'V',
#   'Fe',
#   'Mn'],
#  'There are two main cavities for lithium in the structures labelled M and M .': ['M',
#   'M',
#   'lithium',
#   'structures'],
#  'A M solution of LiClO in a / mixture of propylene carbonate and dimethoxyethane composed the electrolyte .': ['M',
#   'propylene carbonate',
#   'electrolyte'],
#  'The evolution of lattice parameters with radii of M and M cations indicates the anomalous behavior of tincontaining compounds .': ['M',
#   'M cations',
#   'lattice parameters',
#   'radii',
#   'anomalous behavior'],
#  'Depending on the nature of the M ‘ and M ‘ ions the color of the compounds varies from white to black .': ['M',
#   'M'],
#  'All Pb ‘ M ‘ M ‘ PO compounds are isostructural with the alkaline earth analogues .': ['M',
#   'PO',
#   'Pb',
#   'alkaline earth analogues'],
#  'Similarly the variation in the sizes of the M ‘ and M ‘ ions also has no e ! ect on the structural symmetry of these phases .': ['M',
#   'M',
#   'structural symmetry',
#   'sizes'],
#  'Figures and show the plots of the hexagonal a and c parameters of Pb ‘ M ‘ M ‘ PO compounds as a function of the ionic radius of the octahedral site M ‘ and M ‘ cations , respectively .': ['M',
#   'M',
#   'M',
#   'M',
#   'Pb',
#   'PO compounds',
#   'octahedral site',
#   'ionic radius',
#   'c parameters',
#   'hexagonal a'],
#  'This could be due to the presence of Pb ‘ in the type I site and the polarizing nature of M ‘ / M ‘ ions .': ['M',
#   'type',
#   'I site',
#   'polarizing nature'],
#  'A M NaOH solution was used as the aqueous electrolyte .': ['M',
#   'aqueous electrolyte'],
#  "The study of phosphate series of similar composition with M = Co , Mn , M ' = Ni , Cu was continued in .": ['M',
#   'Ni',
#   'Cu',
#   'composition',
#   'Mn',
#   'phosphate'],
#  "The X - ray diffraction patterns of all the singleZr – x ( M = Cd , Sr , Pb ; M ' = .": ['M',
#   'x',
#   'Cd',
#   'Pb',
#   'Sr',
#   'X',
#   'ray diffraction patterns'],
#  'Electrochemical measurements were conducted on a three - electrode system with Ag / AgCl ] counter electrode , and M NaClO aqueous electrolyte .': ['M',
#   'Ag',
#   'three',
#   'counter electrode',
#   'electrode system',
#   'Electrochemical measurements'],
#  'Li , Na ; M & M may adopt two distinct crystallographic forms , denoted “ A ” ] “ lantern units ” are connected .': ['M',
#   'M',
#   'Na',
#   'A',
#   'crystallographic',
#   'lantern units'],
#  'in the way the [ MM Depending on both the stable oxidation number of M or , for instance and on M the chemical nature of X , etc .': ['M',
#   'M',
#   'X',
#   'MM',
#   'oxidation number'],
#  'LiTi adopts the B form only , which corresponds to the well - known NASICON structure inside which the Li ions are located in the six - fold coordinated site that is labeled M .': ['M',
#   'Li ions',
#   'B',
#   'six',
#   'fold coordinated site'],
#  'The lithium ions occupy then a single four - fold coordinated site , forming Li – O – M – O – Li – O inﬁnite chains along of edge - sharing LiO tetrahedra and MO octahedra .': ['M',
#   'Li',
#   'Li',
#   'lithium ions',
#   'O',
#   'O',
#   'O',
#   'MO octahedra',
#   'four',
#   'fold coordinated site'],
#  'Recently many attempts have been reported on mixed M / M phosphates AMM on the octahedral site .': ['M',
#   'octahedral site',
#   'M phosphates'],
#  'But during addition of Al + ions the occupancy of M is increased as additional Li + ions start filling that position to balance charge .': ['M',
#   'Li'],
#  'They also found the second position of lithium at which is later denoted as M .': ['M',
#   'lithium'],
#  'Li + ions reside in two positions : M , which is located between two columns of GeO .': ['M',
#   'Li',
#   'positions'],
#  'In the absence of Al + , Li + ions occupy only M position , but with Al + substitution , M occupancy decreases and M occupancy increases resulting an electrostatic repulsion between these two sites and to minimize the repulsive effect , Li + ion preferentially occupies M position .': ['M',
#   'Al',
#   'Al',
#   'Li',
#   'Li',
#   'sites',
#   'M position',
#   'M position',
#   'occupancy',
#   'occupancy',
#   'M',
#   'electrostatic repulsion'],
#  'Thus the value of is reduced and as M occupancy is reduced , the attractive force between Li + and surrounding oxygen atoms of GeO get reduced .': ['M',
#   'Li',
#   'oxygen atoms',
#   'occupancy',
#   'attractive force'],
#  'These indicate the existence of populated M and M positions by Li atoms .': ['M',
#   'M',
#   'Li atoms'],
#  'The DLi values of M LiPF in the solution electrolyte propylene carbonate were added and were about two orders of magnitude higher than those of the solid inorganic electrolytes .': ['M',
#   'solution electrolyte propylene carbonate',
#   'solid inorganic electrolytes'],
#  'A good reversibility is noticed as illustrated by the same measured value at M at the initial and ﬁnal steps .': ['M',
#   'reversibility'],
#  'Reporting the different equilibrium potential values recorded as a function of the logarithm of the lithium ion concentration , we obtain a good linear depen− dence from M to − expected from Nernst law that is lower than the mV dec .': ['M',
#   'lithium ion concentration',
#   'logarithm',
#   'equilibrium potential',
#   'Nernst law'],
#  'It turns out that this slope is three times larger than the one measured in non aqueous medium , for instance in M LiClO / PC , implying faster kinetics for the former .': ['M',
#   'kinetics',
#   'faster',
#   'non',
#   'aqueous medium'],
#  'To check whether this is also the case for the FePO / LiFePO system , voltamperometry experiments − in different were performed with a scan rate of mV s concentrations of LiNO / HO electrolyte ranging from M to − M .': ['M',
#   'M',
#   'HO electrolyte'],
#  'This is because of insensitiveness of M to the polarization process , which is characterized by capacitances which are much larger than the grain - interior capacitance .': ['M',
#   'polarization'],
#  'Non - Debye behavior of conductivity relaxation is reﬂected in broad maxima in M .': ['M',
#   'conductivity',
#   'relaxation'],
#  'In the past decades , extensive investigations have been carried out on Nasicon - type lithium ion conductors with formula of LiM , M = Ge , Ti , Sn , Zr , Hf .': ['M',
#   'Ti',
#   'Zr',
#   'Ge',
#   'Hf',
#   'Sn'],
#  'Li , Al , Sc and P NMR chemical shifts were referred to M LiCl , M AlCl , M Sc and % HPO aqueous solutions .': ['M',
#   'Al',
#   'Li',
#   'P',
#   'Sc',
#   'Sc',
#   'chemical shifts',
#   'NMR'],
#  'In the past , a link between the size of this bottleneck and the size of the M cation has been established , but there remains some ambiguity as to whether this causal relationship holds when M is a main group element or when multiple substitutions are enacted .': ['M',
#   'M cation',
#   'bottleneck',
#   'group element',
#   'size',
#   'size'],
#  'The M + → Al + + Li + substitution rate was chosen to match the composition of LAGP demonstrated to have the highest conductivity in the series Li + xAlxGe−x spectroscopy to elucidate the ion hopping dynamics in the bulk of these materials .': ['M',
#   'Al',
#   'Li',
#   'Li',
#   'composition',
#   'conductivity',
#   'ion hopping dynamics'],
#  'The conventional NASICON - type solid electrolyte adopts a well - deﬁned structure in the rhombohedral crystal system , where the M + / + cations are , to a certain degree , interchangeable and forming solid solutions .': ['M',
#   'rhombohedral',
#   'solid solutions'],
#  'The PO distortions are recorded in broadened peaks in the Raman spectra , and since each oxygen is shared in a bond with a M + / + cation , this implies an [UNK] on MO units as well .': ['M',
#   'oxygen',
#   'MO units',
#   'PO distortions',
#   'bond'],
#  'The Ca and Sr compounds adopt the lower symmetry Rł space group owing to alternate ordering of M and vacancy along the c - axis , leading to crystallographically distinct MIa and MIb sites .': ['M',
#   'Ca',
#   'Sr',
#   'c',
#   'axis',
#   'vacancy'],
#  'For M and M ′ substituted ions , the valences and ionic radius should be carefully screened to enlarge ions channels and weaken the interaction between mobile ions and skeleton atoms .': ['M',
#   'M',
#   'ionic radius',
#   'skeleton'],
#  'Two typical aqueous conditions on H electrolytes , - M LiCl and - M LiOH , were chosen to study the þ - ion adsorption inﬂuence of LATP surface conditions on H behavior .': ['M',
#   'M',
#   'H behavior',
#   'aqueous conditions electrolytes'],
#  'shows CV curves of the PLE before and after soaking in the - M LiCl electrolyte .': ['M',
#   'CV'],
#  'The electronic conductivity contribution in ionic conductivity dominant solid electrolytes of MX was estimated by the Wagner method using the M / MX / M ’ cell .': ['M',
#   'ionic conductivity',
#   'electronic conductivity',
#   'solid electrolytes',
#   'Wagner method'],
#  'The grain boundary conductivity of LTAP immersed in a M [UNK] LiCl aqueous solution at C for one week was slightly increased .': ['M',
#   'C',
#   'grain boundary conductivity'],
#  'The molar volume , where M is the corresponding molecular weight of the samples .': ['M',
#   'molecular weight',
#   'molar volume'],
#  'M * has been used in the analysis of the electrical properties since it provides the response due to the bulk and eliminates the electrode polarization effect .': ['M',
#   'bulk',
#   'response',
#   'electrical properties',
#   'electrode polarization'],
#  'The shape of the spectrum remains same but the M peak frequency shifts towards higher frequency side as the temperature increases .': ['M',
#   'M',
#   'temperature',
#   'temperature'],
#  'In the real part of the electric modulus , M dispersion is due to the conductivity relaxation .': ['M',
#   'electric modulus',
#   'conductivity relaxation'],
#  'The imaginary part of the M is the peak frequency of the imaginary part of the modulus .': ['M',
#   'modulus'],
#  'The non - Debye behavior observed in the Z and M is shown in Fig .': ['M',
#   'Z'],
#  'Phosphates with the general formula A M ] framework built up by corner - sharing MO octahedra and PO tetrahedra .': ['M',
#   'A',
#   'MO octahedra',
#   'Phosphates'],
#  'The conductivity may be increased by partial substitution of M by trivalent cations as Al , Ga , In , Ti , Sc , Y , La , Cr , Fe .': ['M',
#   'Ti',
#   'Al',
#   'Cr',
#   'Fe',
#   'Sc',
#   'In',
#   'Y',
#   'La',
#   'Ga',
#   'trivalent cations',
#   'conductivity'],
#  'It is evident that conductivities increase with the substitution of M for Hf in the SW solid solution .': ['M',
#   'Hf',
#   'conductivities',
#   'SW solid solution'],
#  'Thus , due to presence of Ga + and Ti + cations near the M and M vacancy sites , the mobility of Li + ion at these sites might increase .': ['M',
#   'Ti',
#   'Li',
#   'Ga',
#   'sites',
#   'M vacancy sites',
#   'mobility'],
#  "Assuming a homogenous distribution of the Li - cations within the glass and glass ceramic samples , the normal site concentration , N , can be calculated from experimental density according to the relation : N ¼ ρNA = M where ρ is the density , NA is the Avogadro ' s number and M is the molecular weight of the compound .": ['M',
#   'density',
#   'molecular weight',
#   'glass',
#   'glass ceramic'],
#  'One example is the telluride compound , NaMTeO , where M is Ni , Co , Zn or Mg .': ['M',
#   'Ni',
#   'Mg',
#   'Co',
#   'Zn',
#   'telluride compound'],
#  'The electrolyte was M LiPF dissolved in EC + DMC + EMC solution .': ['M',
#   'EC',
#   'electrolyte'],
#  'Transition metal carbides , carbonitrides , and nitrides are D materials with a general formula of Mn + XnTx , where M is a transition metal , X can be carbon and / or nitrogen , and T stands for hydroxyl , oxygen , or ﬂuorine .': ['M',
#   'oxygen',
#   'carbon',
#   'Mn',
#   'T',
#   'X',
#   'nitrogen',
#   'hydroxyl',
#   'transition metal',
#   'nitrides',
#   'D materials'],
#  'The diversityis benefited by the flexibility of the NASICON structure that canaccommodate various combinations of A , M and X cations in thestructure where tetrahedral oxoanions cations .': ['M',
#   'A',
#   'X cations'],
#  'NASICON ( M ′ = Al , Y , Fe .': ['M', 'Al', 'Fe', 'Y'],
#  '; M , M ’ = Fe , Zr , Ti , V , Nb , .': ['M',
#   'M',
#   'Ti',
#   'Zr',
#   'V',
#   'Fe',
#   'Nb'],
#  'By remaining the ﬁrst M samples in each matrix , the cycling data are synchronized to the same length .': ['M',
#   'length'],
#  'Such a structure of the M – xA – xR + x atoms are located on the threefold rotation axes and the MoO groups reside on the twofold rotation axes .': ['M',
#   'structure',
#   'threefold rotation axes',
#   'twofold rotation axes'],
#  'Accordingly , the possibility of employing an additional contribution to the luminescence excitation mechanism in order to raise the luminescence intensity allows the M – xMg – xSc phases to be thought of as potentially attractive structures for doping with other rare earths .': ['M',
#   'luminescence excitation mechanism',
#   'luminescence intensity',
#   'doping'],
#  'Their theoretical where M is the molecular mass per formula unit of the substance , Z is the number of formula units per unit cell , and V is the unit - cell volume .': ['M',
#   'V',
#   'Z',
#   'unit cell',
#   'molecular mass per formula unit',
#   'formula units per'],
#  'The electrolyte used was a M NaPF solution in a : mixture of ethylene carbonate and propylene carbonate .': ['M',
#   'propylene carbonate',
#   'ethylene carbonate',
#   'electrolyte'],
#  'This is due to the reduction in the size of the voluminous voids of the M and C types in the structure due to rotation of structural polyhedra .': ['M',
#   'C',
#   'size',
#   'rotation'],
#  'The structural formula of NaSiCons is Ol , where M and M are interstitial vacancy sites , either partially or fully occupied by appropriately sized cations .': ['M',
#   'M',
#   'interstitial vacancy sites',
#   'sized cations'],
#  'In particular , solid electrolyte phases with M = Ge , M = Ti , Ge , and M = Ti , Ta were investigated .': ['M',
#   'Ti',
#   'Ge',
#   'Ge',
#   'Ta',
#   'solid electrolyte'],
#  'The M sites in pure LiTi are fully occupied by lithium ions while M are empty due to the lower potential of M .': ['M',
#   'M',
#   'lithium ions',
#   'M sites',
#   'lower potential'],
#  'But the Ea of grain boundary may vary with the substitutional amount of M + by M + due to the structural change and the degree of densiﬁcation .': ['M',
#   'M',
#   'grain boundary'],
#  'Moreover , it is well known that Li + ions are disordered between M and M positions in Nasicon structure .': ['M',
#   'Li',
#   'M positions'],
#  'It is clear that CQ increases upon heating since growth of M positions occupancy , in which CQ is higher than in M .': ['M',
#   'M positions',
#   'CQ',
#   'CQ',
#   'occupancy',
#   'heating'],
#  'According to Nb NMR data Nb + partially occupy Ti + , M and perhaps M positions in LiTi thus blocking the ionic transport and dramatically dropping down ion conductivity and increasing correlation time τc .': ['M',
#   'M',
#   'Nb',
#   'ion conductivity',
#   'ionic transport',
#   'correlation',
#   'Nb NMR'],
#  'M solution of NaClO in pro - pylene carbonate was used as the separator .': ['M',
#   'pro'],
#  'The structure is highly flexibleand amenable to substitution on the M , A or phosphorussites to form a wide variety of isostructural materials .': ['M',
#   'A',
#   'structure'],
#  'For comparison , Figure S shows the test with the organic electrolyte of M NaPF – PC at K under the same conditions .': ['M',
#   'PC',
#   'organic electrolyte',
#   'conditions',
#   'K'],
#  ', it was confirmed that Na + ion at the M sites in NVP is mobile whereas Na + ion at the M site is immobile , relating to a direct M to M conduction pathway .': ['M',
#   'Na',
#   'Na',
#   'M sites',
#   'M site',
#   'M conduction pathway'],
#  'Each MO octahedron occupied by M is surrounded by and shares corner with six adjacent PO tetrahedrons , and each PO tetrahedron links to and shares corner with four neighboring MO octahedron .': ['M',
#   'PO tetrahedrons',
#   'PO tetrahedron',
#   'MO octahedron',
#   'MO octahedron'],
#  'Conductivity higher than S / cm has been obtained in Li xGe xMxS , in which M represents a trivalent or penta - valent cation .': ['M',
#   'trivalent',
#   'Conductivity'],
#  'The electrolyte consisted of ethylene carbonate / propylene carbonate with M NaClO as the sodium salt and vol .': ['M',
#   'propylene carbonate',
#   'sodium salt',
#   'ethylene carbonate',
#   'electrolyte'],
#  'Impedance proﬁles of M [UNK] LiOH aqueous solution at C for one week .': ['M',
#   'C'],
#  'There is one atom on a M with ≤ x≤ and ≤ y≤ .': ['M', 'atom'],
#  'The crystal structure of this compound was assigned to a monoclinic system with C / c space group and a general structural formula X , where X are large cation polyhedral , M are distorted octahedral , and P the tetrahedral centers .': ['M',
#   'P',
#   'X',
#   'X polyhedral',
#   'crystal structure',
#   'octahedral',
#   'c space group',
#   'C',
#   'distorted',
#   'tetrahedral centers'],
#  'Because Mn dominates on the M , from which the majority of natural alluaudites can be derived .': ['M',
#   'Mn',
#   'natural'],
#  'The crystallization temperature increased with the increase in the radius of M + or R + ion , ranging from C to C for the M - containing samples and C to C for the R - containing samples .': ['M',
#   'M',
#   'R',
#   'R',
#   'C',
#   'C',
#   'C',
#   'C',
#   'radius',
#   'temperature'],
#  'To compare the decomposition ability for different M + or R + ion , the decomposed fraction of MB after UV irradiation for min was calculated .': ['M',
#   'R',
#   'MB',
#   'decomposition ability',
#   'UV irradiation'],
#  'photocatalytic activity , varied largely but no dependence on the radius of M + or R + ion was observed .': ['M',
#   'R',
#   'radius'],
#  'The Nasicon structure is built up of corner - sharing BO octahedra and PO tetrahedra leading to a framework of BPO formulas with interconnected channels where cations can be inserted in two types of sites usually noted M at b wickoff positions .': ['M',
#   'cations',
#   'channels',
#   'sites',
#   'BO octahedra'],
#  'The molecular formula of these materials is AxM , M is a tetravalent cation such us Ti + , Ge + , or Sn + , and X may be P + or Si + .': ['M',
#   'X',
#   'tetravalent cation'],
#  'The wide range of compositional variations of the NASICON family allows for partial or total replacement of the A , M or Si + / P + ions , making them interesting materials for investigations about the influence of different elements in their ionic conductivity .': ['M',
#   'Si',
#   'A',
#   'ionic conductivity'],
#  'NASICON - type has the general formula of LiM where M can be Ti + , Ge + , etc .': ['M',
#   'Ti',
#   'Ge'],
#  'As the oxygen sites are generally fully occupied , the amount of cations in the channels depends upon the oxidation state of the M and X atoms .': ['M',
#   'cations',
#   'X atoms',
#   'channels',
#   'oxygen sites',
#   'oxidation state'],
#  'The electrolyte used was M LiPF salt dissolved in : EC / DMC solution .': ['M',
#   'electrolyte',
#   'EC'],
#  'Metallic sodium was used as a negative electrode and M NaPF solution in : ethylene carbonate and dimethyl carbonate was used as an electrolyte .': ['M',
#   'ethylene carbonate',
#   'Metallic sodium',
#   'electrolyte',
#   'negative electrode'],
#  'HO þ P O M / P OH þ M OH where M is a metal cation .': ['M',
#   'HO',
#   'P O',
#   'M OH',
#   'metal cation'],
#  'Refinement with all Na atom in the two M .': ['M', 'Na atom', 'Refinement'],
#  'Indeed , in order to minimise the electrostatic repulsion between neighbouring cations within the ribbons of M one have two Sb + Ooctahedra as a neighbouring .': ['M',
#   'cations',
#   'Sb',
#   'electrostatic repulsion'],
#  'For example , the splitting of the anti - symmetric stretching − has been correlated with the nd and bending vibrations of PO ionization potential of M in LiMPO materials .': ['M',
#   'PO ionization potential',
#   'splitting',
#   'bending vibrations',
#   'anti',
#   'symmetric stretching'],
#  'where M is the relative molecular mass , a , b , c , a , b , and g are the lattice parameters , NA is the Avogadro constant , and n is the number of molecule in one unit cell .': ['M',
#   'molecule',
#   'lattice parameters',
#   'unit cell',
#   'molecular mass',
#   'Avogadro constant'],
#  'An extra structure at the high - energy side of the LM , M , peak and an edge at eV are observed .': ['M',
#   'LM',
#   'structure'],
#  'Argon L , M , M , Auger spectra , electron excited at two different excess energies .': ['M',
#   'M',
#   'excess energies',
#   'Auger spectra'],
#  'In figure the experimental Ar LM , M , peak obtained at eV excess energy is compared with a line calculated according to our theory .': ['M',
#   'Ar LM'],
#  'In which M and M represent the weight of the dry and wetted separator lm , respectively .': ['M',
#   'M',
#   'dry'],
#  'Based on various physical properties , it was conﬁrmed that there are two phases , M and MPO , in which a similar phase equilibrium energy coexists .': ['M',
#   'phases',
#   'equilibrium',
#   'physical properties',
#   'energy coexists'],
#  'These structural - type materials consist of a three - dimensional network made up of PO tetrahedra , sharing corners with MO octahedra and forming interconnected tunnels , where M + or oxygen ions have freedom of movement .': ['M',
#   'oxygen ions',
#   'three',
#   'MO octahedra'],
#  'The synthesis procedures of the M were quantitatively added and uniformly stirred for h until completely dissolved .': ['M',
#   'h',
#   'stirred',
#   'synthesis'],
#  'The lithium ions , which were known to be in the large M cavity , occupy two M and M ’ subsites with occupation factors of / and / , respectively .': ['M',
#   'M',
#   'lithium ions',
#   'M cavity',
#   'occupation factors'],
#  'Two main types of cavities , denoted M and M , are generally considered .': ['M',
#   'M',
#   'cavities'],
#  'The Fourier difference technique revealed that residual nuclear densities remain at two different f positions ; they correspond to the M sites discussed in the introduction : we denote them M and M ’ , respectively .': ['M',
#   'M',
#   'M sites',
#   'f positions',
#   'nuclear densities',
#   'Fourier difference technique'],
#  'It appeared that convergence was achieved for occupancy factors close to / and / for M and M ’ , respectively .': ['M',
#   'M',
#   'occupancy factors'],
#  'In the following diffusion pathway , the faces shared between two adjacent tetrahedra are given in brackets : M .': ['M',
#   'diffusion pathway'],
#  'M or M ’ occupied by lithium in the neighbouring M cavities .': ['M',
#   'M',
#   'lithium',
#   'M cavities'],
#  'The occupation of M or of M ’ can indeed entail slight but signiﬁcant changes in the position of the Ti ions in the neighbouring TiO octahedra .': ['M',
#   'M',
#   'Ti ions',
#   'occupation'],
#  'Since this should hold , but with a different shift , for Li in both the M and the M ’ site , a total of lines could be assumed , which is not far from the observation .': ['M',
#   'Li'],
#  'This study shows a satisfactory agreement between neutron and XRD data on the one hand and Li NMR data on the other hand for LiTi , showing that Li occupies the M and M ’ sites within the M cavity .': ['M',
#   'Li',
#   'M',
#   'M cavity',
#   'neutron',
#   'Li NMR'],
#  'The lithium cations reside in two inequivalent sites : M , in the center of inversion , with sixfold oxygen coordina tion , and M , around the threefold axis , with eightfold oxygen coordination .': ['M',
#   'lithium cations',
#   'M',
#   'threefold axis',
#   'eightfold oxygen coordination'],
#  "The incorporation of M ' + trivalent cations into the Ti + site increases the ionic conductivity of the material .": ['M',
#   'Ti',
#   'ionic conductivity'],
#  'This study concluded that the solid - solution doping of supervalent cations intothe M and hence the electrochemical properties .': ['M',
#   'electrochemical properties'],
#  'F : Filter , M : Mirrors , GP : Glass plate , L : Lens , P : Polarizer , l / : Half wave plate , MD : Motor Driver , PMT : Photomultiplier tube , NPP : Reference material .': ['M',
#   'GP',
#   'MD',
#   'Polarizer',
#   'Motor Driver',
#   'Photomultiplier'],
#  'In this structure , the partial substitution of the Ti + cation by a trivalent cation , M + , such as Al + , Ga + , In + , Sc + , Y + , La + , Cr + or Fe + , generates a deﬁciency in positive charge , which is compensated by additional Li + ions , leading to the Li + xMxTi − x system .': ['M',
#   'Ti',
#   'Cr',
#   'Fe',
#   'Sc',
#   'In',
#   'Y',
#   'La',
#   'trivalent cation'],
#  'The anode compartment was filled with organic electrolyte of M NaClO in propylene carbonate and was tightly sealed with NASICON .': ['M',
#   'propylene carbonate',
#   'organic electrolyte'],
#  'At low - frequency region , M ′ approaches zero as frequency decreases for all measuring temperatures .': ['M',
#   'low',
#   'frequency region',
#   'temperatures'],
#  'At higher frequency region , M ′ gradually increases as frequency increases and tends to be frequency independent and approaches a constant value .': ['M',
#   'higher frequency region'],
#  'The entire cell was assembled with a liquid electrolyte of M LiCiO in Propylene carbonate in an argon - ﬁlled glove box .': ['M',
#   'Propylene carbonate',
#   'liquid electrolyte'],
#  'By increasing the temperature , peak M progressively disappears , due to fast site exchange in the time of the NMR experiment , and the centre - of - mass of the spectrum shifts downfield , so revealing a more ionic character of the Li + ions .': ['M',
#   'site',
#   'ionic character',
#   'NMR experiment',
#   'temperature'],
#  'In addition , hexa - valent tungsten ions strongly bond to oxide ions , as a result , the M + ions are able to migrate readily in the layered structure .': ['M',
#   'oxide ions',
#   'layered structure',
#   'tungsten'],
#  'The M @ maximum associated capacitance is bulk characteristic .': ['M',
#   'capacitance',
#   'bulk characteristic'],
#  'Two types of silver cations M and M are found to have different coordination requirements shown by the bond valence sum calculations .': ['M',
#   'M',
#   'silver cations',
#   'coordination requirements',
#   'bond valence sum calculations'],
#  'In the network mentioned A is an alkali metal ion and M is a multivalent one .': ['M',
#   'A',
#   'alkali metal ion'],
#  'In broad senses , NASICONs are a class of solid materials with a general formula of [UNK] , where “ A ” could be alkali metal ions , alkaline earth metal ions , hydrions , ammonium ions , transition metal cations , and vacancies , “ M ” usually stands for transition metals or metalloids , and P could be partially substituted by Si or As .': ['M',
#   'Si',
#   'P',
#   'A',
#   'As',
#   'ammonium ions',
#   'transition metals',
#   'alkali metal ions',
#   'solid materials',
#   'transition metal cations',
#   'alkaline earth metal ions'],
#  'With matproj package of Pymatgen , we found NASICONtype compounds with the chemical formula of LixM , where x could be from to and M is distributed mainly over Bi , Co , Cr , Fe , Ge , In , Mn , Nb , Ni , Sb , Sc , Ti , V , and Zr .': ['M',
#   'Ni',
#   'Ti',
#   'Zr',
#   'Ge',
#   'V',
#   'Cr',
#   'x',
#   'Fe',
#   'Co',
#   'Mn',
#   'Nb',
#   'Sc',
#   'In',
#   'Sb',
#   'Bi'],
#  'The overlap of the bands between O , P and M could be observed , which indicates the high degree of orbital hybridization .': ['M',
#   'P',
#   'O',
#   'bands',
#   'orbital hybridization'],
#  'West and co - workers investigated the M – N rule for several solid electrolytes ; such as , various ion exchanged β - aluminas , Li + xZn - xGeO and silver ion conducting glasses .': ['M',
#   'Li',
#   'solid electrolytes',
#   'silver ion conducting glasses'],
#  'For example , in the compounds of general formula LiM−xAx thecell parameters a and c depend on the M and A cation size .': ['M',
#   'A cation size',
#   'c'],
# ...
#   'reaction',
#   'high yield',
#   'aldehydes',
#   'esters'],
#  'Reagent - grade CHCOOLi · HO were used as starting materials .': ['HO'],
#  'Brown single crystals of NaNiFeMoO · HO in a molar ratio of : : : .': ['HO',
#   'molar ratio',
#   'single crystals'],
#  'First , stoichiometric amounts of NaNO , MMoO · HO were dissolved in distilled water , then mixed with aqueous glycine solution .': ['HO',
#   'aqueous glycine solution'],
#  'Figure depicts a three - dimensional schematic illustration of the total and the proton conductivity as functions of O and HO partial pressures .': ['HO',
#   'O',
#   'three',
#   'proton conductivity',
#   'partial pressures'],
#  'A precursor sol of LAGP was prepared by mixing CHCOOLi , Ge , HPO , iso - propanol , CHCOOH and HO .': ['HO',
#   'Ge',
#   'sol'],
#  'During the calcination , they decomposed into manganese oxides , HO .': ['HO',
#   'manganese oxides',
#   'calcination'],
#  'Stoichiometric mixtures of the metal oxides and ammonium dihydrogen phosphate were heated in air at C for h to eliminate HO and NH .': ['HO',
#   'NH',
#   'heated',
#   'metal oxides',
#   'h',
#   'air',
#   'C'],
#  'The initial compounds used were of chemically pure grade : CdO , CuO , Sr , and ZrOCl ⋅ HO , NHHPO .': ['HO',
#   'Sr',
#   'chemically pure grade'],
#  'Stoichiometric quantities of ZrOCl ¢ HO , AgNO , and were dissolved in a minimal amount of water under stirring at room temperature .': ['HO',
#   'stirring',
#   'room temperature'],
#  'The chemical shifts were measured using as references HPO for P and HO for H .': ['HO',
#   'P',
#   'H',
#   'chemical shifts'],
#  'As a substrates NHHPO , NaSiO · HO and ZrO · xHO were used .': ['HO'],
#  'In the sol – gel process , SnCl · HO and Zn · HO were used as precursors , CHOH was used as solvent , acetone and acetic acid were used as chelating agent , the obtained sol was dried at [UNK] for h and the obtaining gel was sintered at , , , and [UNK] for h , respectively .': ['HO',
#   'acetone',
#   'acetic acid',
#   'sintered',
#   'dried',
#   'chelating agent',
#   'gel',
#   'gel',
#   'sol',
#   'sol',
#   'h',
#   'h'],
#  'Similar variations were observed for instance by Hong for a K substitution of which the size is close to the HO one .': ['HO',
#   'K',
#   'size'],
#  'The absorption band at cm− is due to the deformation vibration modes of the HO .': ['HO',
#   'absorption band'],
#  'Specifically , the problem in lithium residual coating on the surface of NCA , derived from the chemical adsorption of HO or CO in air , will induce the formation of cathode gel , degrading the performance .': ['HO',
#   'CO',
#   'air',
#   'performance',
#   'cathode gel'],
#  'While the intrinsic low electrical conductivity and direct attacking from HO restrict further improvement of electrochemical performance .': ['HO',
#   'electrochemical performance',
#   'electrical conductivity'],
#  'Secondly , high - quality nitrogen - doped carbon layer can prevent the corrosion caused by HO in charge - discharge process , and improve the electrical conductivity of materials .': ['HO',
#   'electrical conductivity',
#   'nitrogen doped carbon layer'],
#  'Simultaneously , the resultant H + will react with the NaCO to release CO and HO and caused further activations of NHHPO to obtain the NVP / C after prolong calcination of the NVP precursor .': ['HO',
#   'CO',
#   'H',
#   'calcination'],
#  'NASICON - type compounds constitute a large class of materials with the general formula AxB , whereА = H , Li , Na , K , HO , or NHand B = In , Sc , Fe , V , Zr , Ti , Hf , Sn , Ge , etc .': ['HO',
#   'Ti',
#   'Zr',
#   'Li',
#   'K',
#   'Na',
#   'Ge',
#   'Hf',
#   'V',
#   'Sn',
#   'Fe',
#   'Sc'],
#  'The homogenized mixture was first heated from °C up to °C to slowly evaporate HO .': ['HO',
#   'heated'],
#  'During this heat treatment , the polymer matrix was pyrolyzed and NOx , CO , and HO evolved as gaseous products .': ['HO',
#   'CO',
#   'heat treatment',
#   'polymer matrix',
#   'gaseous products'],
#  'Because the samples were stored in air , the weight loss below °C can be attributed to release of HO and CO .': ['HO',
#   'CO'],
#  'suggested that the replacement of Na + ions with HO + plays a critical role in the NASICON structural degradation in acidic solutions .': ['HO',
#   'Na'],
#  'The observed gradual microstructural degradation matches very well the systematic changes of the XRD peak patterns depicted in Figure d , which shows that HO + −NASICON species .': ['HO'],
#  'The HO + −NASICON phase peak corresponding to the monoclinic NASICON structure shifted considerably after d and d of treatment with HCl and CHCOOH - modified seawater solutions , respectively .': ['HO',
#   'phase',
#   'treatment',
#   'seawater solutions'],
#  'In order to conduct a more detailed investigation , Cl - , Na + , and HO + element distributions were analyzed and profiled for each sample via TOF−SIMS after various treatment periods .': ['HO',
#   'Na',
#   'Cl',
#   'treatment periods'],
#  'These simultaneous phenomena can provide available sites for HO + species to occupy .': ['HO',
#   'sites'],
#  'The results displayed that halogen doping effectively improved the chemical stability in CO and HO steam of BCG without damaging the structure and morphology of BCG .': ['HO',
#   'CO',
#   'chemical stability',
#   'halogen doping'],
#  'Namely , it is thought that HO molecules rapidly adsorbed on the uncovered counter electrode in comparison with the sensing electrode covered with the binary carbonate layer , immediately after the humidity change from % to % RH , but the amount of HO molecules adsorbed on the sensing electrode became close to that on the counter electrode after several seconds .': ['HO',
#   'HO',
#   'humidity change',
#   'binary carbonate layer',
#   'sensing electrode',
#   'sensing electrode'],
#  'On the other hand , the diffusion of HO through the dense auxiliary layer was considered to be much slower than that through the porous auxiliary layer .': ['HO',
#   'porous auxiliary layer',
#   'dense auxiliary layer'],
#  'Also , the reason for the potential changes with RH is not identified clearly yet , but some electrochemical reaction with HO may relate to the potential change .': ['HO',
#   'electrochemical reaction',
#   'RH'],
#  'Heating of H ? XZr ? XMX ? HO leads to significant changes of XRPD patterns due to material dehydration .': ['HO',
#   'H',
#   'material dehydration',
#   'Heating'],
#  'Conductivity increase at low temperatures can be explained by conductivity of water sorbed on the surface of H ? XZr ? XMX ? HO particles .': ['HO',
#   'H',
#   'conductivity',
#   'Conductivity',
#   'low temperatures'],
#  'Dehydration of HZr ? HO i s accompanied by increase in the a and decrease of the c lattice parameters ( Fig .': ['HO',
#   'c lattice parameters'],
#  'In hydrated material oxygen atom of HO + ion is localized in the M site .': ['HO',
#   'oxygen atom',
#   'M site'],
#  'It has been acknowledged that water vapor or OH group from the dissociated HO plays a vital role during the CO sensing process .': ['HO',
#   'OH group',
#   'CO sensing'],
#  'addition to O , HO , N , CO molecules also possibly diffused from the cathodes to the Li anodes to react with the metallic Li .': ['HO',
#   'Li',
#   'CO',
#   'O',
#   'N',
#   'metallic',
#   'cathodes',
#   'Li anodes'],
#  'In Li - air batteries with aqueous electrolytes , Li + conducting membranes becomes indispensable to separate the Li anodes and the aqueous electrolytes because the direct contact of HO and Li can induce severe reactions even for a very short time .': ['HO',
#   'Li',
#   'Li',
#   'aqueous electrolytes',
#   'aqueous electrolytes',
#   'Li anodes'],
#  'battery consisting of Li - Al / LiPON / LATP / aqueous M LiCl / Pt exhibits a room - temperature open circuit voltage O + HO = LiOH .': ['HO',
#   'Al',
#   'Li'],
#  'The corresponding Li - air cell of Li / PEO – LiTFSI / LATP / HAc – HO – LiAc / Pt black shows a low polarization for Li dissolution and deposition at a current density even as high as mA / cm , indicating a good charge and discharge recyclability .': ['HO',
#   'Li',
#   'Li',
#   'Li',
#   'charge',
#   'current density',
#   'dissolution',
#   'deposition'],
#  'In a battery cell , a porous polypropylene ﬁlm impregnated with the HAc – HO – LiAc aqueous solution provides electrolyte to connect the LATP LICM and the air cathode .': ['HO',
#   'porous polypropylene',
#   'electrolyte',
#   'battery cell',
#   'air cathode'],
#  'NASICON - type compounds constitute a large class of materials with the general formula AxB , where A = H , Li , Na , K , HO , or NHand B = In , Sc , Fe , Zr , Ti , Hf , Sn , Ge , etc .': ['HO',
#   'Ti',
#   'Zr',
#   'Li',
#   'K',
#   'Na',
#   'Ge',
#   'Hf',
#   'Sn',
#   'Fe',
#   'Sc'],
#  'Firstly , the mixture was heated at [UNK] for h and then at [UNK] for h to decompose HO , NH and CO .': ['HO',
#   'CO',
#   'NH',
#   'heated',
#   'h',
#   'h'],
#  'The initial mixture was grounded with acetone for h in an agate mortar and heated at K for day , which results in the release out of NH , HO , and CO gases .': ['HO',
#   'NH',
#   'acetone',
#   'CO gases',
#   'heated',
#   'h',
#   'K',
#   'agate mortar',
#   'day'],
#  'Then , a La - related catalyst solution , methanol , was used to dissolve LaCl bold dot HO to obtain a La concentration of mol / m , which was spin coated on the surface of the SnO thin films .': ['HO',
#   'methanol',
#   'La'],
#  'The cells were assembled in an argon ﬁlled glove box under controlled O and HO traces .': ['HO',
#   'O'],
#  'From propellant chemistry , the oxidizing valency of LiNO is , Ni HO is , NHHPO is zero and the reducing valency of glycine is þ .': ['HO',
#   'Ni',
#   'reducing valency',
#   'oxidizing valency',
#   'propellant',
#   'glycine'],
#  'In the case of glycine – nitrate combustion , the derivatives are gaseous N , CO and HO .': ['HO',
#   'CO',
#   'nitrate combustion',
#   'glycine',
#   'gaseous N'],
#  'Similar to the reactions in sensor A , a couple of electrochemical reactions → CO + HO + Na By treating Eqs .': ['HO',
#   'CO',
#   'Na',
#   'reactions',
#   'electrochemical reactions'],
#  'Some researchers have already reported the preparationof Ti + water - soluble precursor by dissolution of Ti metalin hydrogen peroxide and ammonia solution , and usingthe metal alkoxides precursors of · HO .': ['HO',
#   'Ti',
#   'dissolution',
#   'hydrogen peroxide',
#   'ammonia solution'],
#  'It is guessed that the LERHF immersed in DMF can prevent the corrosion by HO and CO from ambient air to avoid aging effect of ionic conductivity .': ['HO',
#   'CO',
#   'ionic conductivity',
#   'corrosion',
#   'ambient air'],
#  'The sample was digested using hydrogen ﬂuoride and top up to ml with HO .': ['HO',
#   'ml'],
#  'A higher signal of the vibrational modes of HO was measured on grain boundaries than in the grain interior on the sample surface as well as on the fractured surface of sintered specimens .': ['HO',
#   'grain boundaries',
#   'grain',
#   'vibrational',
#   'sintered specimens'],
#  'The current responses were hardly affected by the coexistence of CO and HO .': ['HO',
#   'CO',
#   'coexistence',
#   'current responses'],
#  'Stability of the response current to NO or NO on changes in the concentration of CO or HO coexistent .': ['HO',
#   'CO',
#   'NO',
#   'NO'],
#  'High purity LiOH · HO were used as raw materials .': ['HO',
#   'High purity',
#   'raw materials'],
#  'To avoid contamination by ambient HO or CO ( Fig .': ['HO', 'CO'],
#  'The volatile and / or combustible gases such as N , HO and nascent O escaped from a ﬁring container leaving behind voluminous foaming ﬁne powder occupying the entire volume of the container .': ['HO',
#   'N',
#   'volatile',
#   'combustible gases'],
#  'A stoichiometric mixture was mixed thoroughly in an agate mortar and heated at °C for h to drive away NH and HO and other gaseous products .': ['HO',
#   'NH',
#   'heated',
#   'gaseous',
#   'h',
#   'agate mortar'],
#  'A typical synthesis of LiFe · HO was dissolved in mL dilute HNO solution to form solution B , then the solution A and solution B were mixed together .': ['HO',
#   'B A B'],
#  'Metallic Ti has been dissolved in % HO then NaCO and % NHOH HO solution in water have been added .': ['HO',
#   'Ti',
#   'Metallic'],
#  'Care must also be given to prevent the ingress of either CO or HO , which can react with both the Li anode and the LiO cathode .': ['HO',
#   'CO',
#   'Li anode'],
#  'Although signiﬁcant progress has been made by many researchers , serious problems remain to be solved , such as decomposition of the non - aqueous electrolyte by the reaction product of the super oxide , reduction of the carbon electrode during the charging process , and the blocking of HO and CO present in air .': ['HO',
#   'CO',
#   'decomposition',
#   'reduction',
#   'reaction product',
#   'charging process',
#   'super oxide',
#   'non',
#   'aqueous electrolyte',
#   'air'],
#  'Here means adsorbed species derived from HO or O .': ['HO', 'O', 'adsorbed'],
#  'These phenomena suggest that the O and HO involved in the sensing reactions are not supplied directly from gas phase , but through some form of absorption in the sensing layer .': ['HO',
#   'O',
#   'gas phase',
#   'absorption',
#   'sensing reactions',
#   'sensing layer'],
#  'Proper amounts of LiOH · HO , TiO and NHHPO were homogeneously mixed and preheated at °C in air for h to decompose out HO and NH , then milled again and finally sintered at °C for h in a muffle furnace .': ['HO',
#   'HO',
#   'NH',
#   'sintered',
#   'milled',
#   'preheated',
#   'muffle furnace',
#   'again',
#   'h',
#   'h',
#   'air'],
#  'b can be ascribed to the melt and subsequent decomposition of NHHPO , corresponding to the weight loss in TG curves by releasing of NH and HO .': ['HO',
#   'NH',
#   'decomposition'],
#  'La HO were used as sources of La and Cr , respectively .': ['HO',
#   'Cr',
#   'La',
#   'La'],
#  'Double phosphates with the NASICON structure belong to aclass of compounds with the general formula AxB , HO , NH , and B = In , Sc , Fe , Zr , Ti , Hf , Sn , Ge , etc .': ['HO',
#   'Ti',
#   'Zr',
#   'Ge',
#   'Hf',
#   'NH',
#   'Sn',
#   'Fe',
#   'Sc',
#   'Double phosphates'],
#  '$ HO and NHHPO Starting reagents , NaCl , ZrOCl were previously dissolved in distilled water .': ['HO',
#   'distilled water'],
#  'This electrode had operated with an aqueous electrolyte for a long period , and they reported a high stable discharge performance in the Li / solid electrolyte / NHCl in HO / air cell for nearly months .': ['HO',
#   'air cell',
#   'stable discharge performance',
#   'Li solid electrolyte',
#   'aqueous electrolyte',
#   'electrode'],
#  'Regarding the mass spectroscopy results , the followedcompounds are C , N , O , HO , N , CO , NO , O , CO and NO .': ['HO',
#   'CO',
#   'CO',
#   'O',
#   'O',
#   'C',
#   'N',
#   'N',
#   'NO',
#   'NO',
#   'mass spectroscopy'],
#  'Dahn has suggested that the capacity fading mechanism of the aqueous lithium - ion battery is related to the decomposition of HO , material dissolution in aqueous electrolyte , and structural changes of the electrode materials , and demonstrated that the main cause for the capacity loss of the VO into the bulk electrolyte .': ['HO',
#   'VO',
#   'decomposition',
#   'capacity loss',
#   'material',
#   'capacity fading mechanism',
#   'aqueous electrolyte',
#   'electrode',
#   'bulk electrolyte'],
#  'As a base gas , compressed air was used to measure the response to SO , while a gas mixture of % O and N was used in the case of the response measurement towards other gases like CO , CO , CH , HO , H , NO , and NH .': ['HO',
#   'CO',
#   'CO',
#   'NH',
#   'SO',
#   'H',
#   'NO',
#   'CH',
#   'response',
#   'response',
#   'gases',
#   'compressed air',
#   'base gas'],
#  'The response to HO is very complicated and not further illustrated here .': ['HO'],
#  'First , the potential difference increases suddenly when the gas including HO is introduced .': ['HO',
#   'gas'],
#  'cells were assembled in an Ar - filled glove - box with HO and O contents less than ppm .': ['HO',
#   'O',
#   'ppm'],
#  'n HO , are formed upon mixing of a solution of orthophosphoric acid taken most often in a large excess with a solution of EIV salt or oxide .': ['HO',
#   'oxide',
#   'n'],
#  'HO have shown that they all belong to the monoclinic system , have layered structures and the crystal morphology .': ['HO',
#   'layered structures',
#   'crystal morphology'],
#  ...}

# %%
pre_sent = []

# %%
for idx, (sent, entity_list) in enumerate(merge_entity.items()):
    entities = list(set(entity_list))

    if len(entities) < 2:
        continue
    else:
        temp = []
        for i in range(len(entities)-1):
            for j in range(i+1, len(entities)):
                temp.append((entities[i], entities[j]))
        for t in range(len(temp)):
            try:
                h0, h1 = sent.index(temp[t][0]), sent.index(temp[t][-1])
                t0, t1 = h0 + len(temp[t][0]) + 1, h1 + len(temp[t][-1]) + 1
                if h0 > h1:
                    e1_sent = sent[0:h0] + "<e2>" + temp[t][0] + "</e2> " + sent[t0:]
                    e2_sent = e1_sent[0:h1] + "<e1>" + temp[t][-1] + "</e1> " + e1_sent[t1:]
                    pre_sent.append(e2_sent)
                else:
                    e2_sent = sent[0:h1] + "<e2>" + temp[t][-1] + "</e2> " + sent[t1:]
                    e1_sent = e2_sent[0:h0] + "<e1>" + temp[t][0] + "</e1> " + e2_sent[t0:]
                    pre_sent.append(e1_sent)
            except:
                continue

# %%
for ele in pre_sent:
    if "<e1>" not in ele:
        pre_sent.remove(ele)
        continue
    elif "</e1>" not in ele:
        pre_sent.remove(ele)
        continue
    elif "<e2>" not in ele:
        pre_sent.remove(ele)
        continue
    elif "</e2>" not in ele:
        pre_sent.remove(ele)
        continue

# %%
len(pre_sent)
# Out:
# 302638

# %%
for i in range(len(pre_sent)):
    with open("./test.tsv", 'a', encoding='utf-8') as f:
        f.write("Other")
        f.write("\t")
        f.write(pre_sent[i] + "\n")
